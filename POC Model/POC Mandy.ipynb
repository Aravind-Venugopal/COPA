# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
import pyLDAvis
import pyLDAvis.gensim
from nltk.corpus import stopwords
import glob
from datetime import datetime
import statistics
# Out:
# //anaconda3/lib/python3.7/site-packages/nltk/decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: ""
# //anaconda3/lib/python3.7/site-packages/nltk/lm/counter.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence, defaultdict

# %% [markdown]
# # Cleaning Data and concatenate three datasets

# %%
data = []
for filename in glob.glob('*.csv'):
    data.append(filename)
data
# Out:
# ['Parsed Magazine.csv', 'wiki_formal_total_clean.csv', 'COPA_Blogs.csv']

# %%
wiki = pd.read_csv(data[1])
# Only take Date, Title, Content and Author into consideration since magazine does not have likes
wiki = wiki[['Date', 'Title', 'Content', 'Author']]
wiki['Date'] = [d[:-3] for d in wiki['Date']]
wiki['Resource'] = 'Wiki'
wiki['Author'] = [a.strip() for a in wiki['Author']]
wiki.head()
# Out:
#       Date                                              Title  \
# 0  2017-05  Are there any service centers that routinely w...
# 1  2018-09                                        Door Decals
# 2  2017-07  Nose Wheel Pant and Strut Beating at Oshkosh 2017
# 3  2016-08           Oil Door Support for Summer Time Cooling
# 4  2016-03                          Prop Strike Advice Needed
#
#                                              Content         Author Resource
# 0  Title says it all.It is often hard for me to g...        ctrease     Wiki
# 1  Looking for right side door stripe decals.As i...     Mark Craig     Wiki
# 2  Yesterday, I made my first trek over to Oshkos...   Stuart Simek     Wiki
# 3  I am based in Colorado Springs, CO and often s...   Michael Samp     Wiki
# 4  Had a prop strike in my SR-20 this past weeken...  John Shaeffer     Wiki

# %%
magazine = pd.read_csv(data[0])
magazine_date_list = list(magazine['Magazine'].unique())
# Get the month of magazine from its name
magazine_date_dict = {magazine_date_list[0]: '2015-01', magazine_date_list[1]: '2019-01', magazine_date_list[2]: '2015-07', magazine_date_list[3]: '2019-04', magazine_date_list[4]: '2019-06', magazine_date_list[5]: '2018-01', magazine_date_list[6]: '2017-09', magazine_date_list[7]: '2016-09', magazine_date_list[8]: '2017-11', magazine_date_list[9]: '2015-05', magazine_date_list[10]: '2015-09', magazine_date_list[11]: '2006-09', magazine_date_list[12]: '2018-06', magazine_date_list[13]: '2019-07', magazine_date_list[14]: '2017-04', magazine_date_list[15]: '2016-04', magazine_date_list[16]: '2018-11', magazine_date_list[17]: '2015-09', magazine_date_list[18]: '2019-03', magazine_date_list[19]: '2006-11', magazine_date_list[20]: '2016-01', magazine_date_list[21]: '2019-05', magazine_date_list[22]: '2016-03', magazine_date_list[23]: '2016-05', magazine_date_list[24]: '2006-07', magazine_date_list[25]: '2017-06', magazine_date_list[26]: '2018-07', magazine_date_list[27]: '2018-09', magazine_date_list[28]: '2017-01', magazine_date_list[29]: '2012-11'}
magazine['Magazine'] = magazine['Magazine'].map(magazine_date_dict)
magazine.columns = ['Date', 'Title', 'Content', 'Author']
magazine['Resource'] = 'Magazine'
magazine.head()
# Out:
#       Date               Title  \
# 0  2015-01  President's Column
# 1  2015-01           COPA News
# 2  2015-01       Regional News
# 3  2015-01  Cirrus Perspective
# 4  2015-01    Member Spotlight
#
#                                              Content          Author  Resource
# 0  JANUARY FEBRUARY 20154CIRRUS PILOTAs this is b...             NaN  Magazine
# 1  JANUARY FEBRUARY 20156CIRRUS PILOTWith this is...             NaN  Magazine
# 2  JANUARY FEBRUARY 201512CIRRUS PILOTby GIL WILL...  GIL WILLIAMSON  Magazine
# 3  JANUARY FEBRUARY 201518CIRRUS PILOTIts hard to...             NaN  Magazine
# 4  JANUARY FEBRUARY 201522CIRRUS PILOTCirrus Pilo...    KIM BLONIGEN  Magazine

# %%
blog = pd.read_csv(data[2], encoding = 'unicode_escape')
blog = blog[blog.columns[1:]]
blog = blog[['Date', 'Title', 'Body', 'Author']]
blog.columns = ['Date', 'Title', 'Content', 'Author']
blog['Date'] = [d.split(' ')[0].split('/')[2] + '-' + d.split(' ')[0].split('/')[0] for d in blog['Date']]
blog['Resource'] = 'Blog'
blog.head()
# Out:
#       Date                                              Title  \
# 0  2018-12  CAPS Deployment Anomaly at Colorado Springs, C...
# 1   2016-1  CAPS: How Low Can You Go? Or How High Do You N...
# 2   2017-9  "Reach the Unreachable" safety column in COPA ...
# 3  2018-10  ??That Sounds Expensive?? -- It Happened to ...
# 4   2017-6  Guest Editor column to Special Safety Issue of...
#
#                                              Content      Author Resource
# 0  by RICK BEACH, COPA?? SAFETY CHAIR\nThis unusu...  Rick Beach     Blog
# 1  Every Cirrus aircraft built has a parachute sy...  Rick Beach     Blog
# 2  (This article appears as the safety column in ...  Rick Beach     Blog
# 3  This column will appear in the Nov/Dec 2018 is...  Rick Beach     Blog
# 4  A Note from the Guest Editor\nThis June 2017 i...  Rick Beach     Blog

# %%
pdList = [magazine, wiki, blog]
# Combine three datasets together
df = pd.concat(pdList)
df.reset_index(drop = True, inplace = True)
df.head()
# Out:
#       Date               Title  \
# 0  2015-01  President's Column
# 1  2015-01           COPA News
# 2  2015-01       Regional News
# 3  2015-01  Cirrus Perspective
# 4  2015-01    Member Spotlight
#
#                                              Content          Author  Resource
# 0  JANUARY FEBRUARY 20154CIRRUS PILOTAs this is b...             NaN  Magazine
# 1  JANUARY FEBRUARY 20156CIRRUS PILOTWith this is...             NaN  Magazine
# 2  JANUARY FEBRUARY 201512CIRRUS PILOTby GIL WILL...  GIL WILLIAMSON  Magazine
# 3  JANUARY FEBRUARY 201518CIRRUS PILOTIts hard to...             NaN  Magazine
# 4  JANUARY FEBRUARY 201522CIRRUS PILOTCirrus Pilo...    KIM BLONIGEN  Magazine

# %% [markdown]
# # Find Metrics

# %%
# Create a model for topic classification based on the dataset we have 
# (It may cause some problems because the model will be applied to the dataset later to give each content a topic.)
# (The problem can be solved when we get the entire dataset since we can take part of the contents as corpus.)

# Get some stop words
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
# Convert contents to list
data = df.Content.values.tolist()

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           passes=10)

# pprint(lda_model.print_topics(num_words = 5))
# Get 20 related topics
doc_lda = lda_model[corpus]

# %%
# Put contents into model and assign each content to a topic
cleanlist = data
texts1 = [[word for word in doc.lower().split() if word not in stop_words] for doc in cleanlist]
corpus1 = [id2word.doc2bow(text) for text in texts1]
resultlist = lda_model.get_document_topics(corpus1)

# %%
# Build a dictionary containing the index of content and its topic classification
topic_dict = {}
for i, result in enumerate(resultlist):
    temp = 0
    topic = 0
    for j in range(len(result)):
        if result[j][1] > temp:
            temp = result[j][1]
            topic = j
    topic_dict[i] = topic

df['Topic Category'] = [v for k, v in topic_dict.items()]

# %%
# Calculate the number of articles written by every author
author_list = list(df['Author'].dropna().unique())
author_dict = {}
for a in author_list:
    author_dict[a] = len(df[df['Author'] == a])

# %%
# Assign score to the resource, recency and author of an article
resource_rank = {'Magazine': 3, 'Wiki': 2, 'Blog': 1}
df['Resource Score'] = df['Resource'].map(resource_rank)
df['Recency Score'] = [1 / round(abs(datetime.strptime('2019-12', '%Y-%m') - datetime.strptime(d, '%Y-%m')).days / 31) for d in df['Date']]
df['Author Score'] = df['Author'].map(author_dict)
df['Author Score'] = df['Author Score'].fillna(0)

# %%
# Normalize three scores
df['Resource Score'] = (df['Resource Score'] - min(df['Resource Score'])) / (max(df['Resource Score']) - min(df['Resource Score']))
df['Recency Score'] = (df['Recency Score'] - min(df['Recency Score'])) / (max(df['Recency Score']) - min(df['Recency Score']))
df['Author Score'] = (df['Author Score'] - min(df['Author Score'])) / (max(df['Author Score']) - min(df['Author Score']))

# %%
df.head()
# Out:
#       Date               Title  \
# 0  2015-01  President's Column
# 1  2015-01           COPA News
# 2  2015-01       Regional News
# 3  2015-01  Cirrus Perspective
# 4  2015-01    Member Spotlight
#
#                                              Content          Author  \
# 0  JANUARY FEBRUARY 20154CIRRUS PILOTAs this is b...             NaN
# 1  JANUARY FEBRUARY 20156CIRRUS PILOTWith this is...             NaN
# 2  JANUARY FEBRUARY 201512CIRRUS PILOTby GIL WILL...  GIL WILLIAMSON
# 3  JANUARY FEBRUARY 201518CIRRUS PILOTIts hard to...             NaN
# 4  JANUARY FEBRUARY 201522CIRRUS PILOTCirrus Pilo...    KIM BLONIGEN
#
#    Resource  Topic Category  Resource Score  Recency Score  Author Score
# 0  Magazine               1             1.0       0.044783      0.000000
# 1  Magazine              13             1.0       0.044783      0.000000
# 2  Magazine               2             1.0       0.044783      0.217391
# 3  Magazine               1             1.0       0.044783      0.000000
# 4  Magazine               1             1.0       0.044783      0.217391

# %% [markdown]
# # Input new data and return searching results

# %%
# Search for a term or a sentence
text = ['The engine does not work']
cleanlist = text
texts1 = [[word for word in doc.lower().split() if word not in stop_words] for doc in cleanlist]
corpus1 = [id2word.doc2bow(t) for t in texts1]
result = lda_model.get_document_topics(corpus1)

temp = 0
topic = 0
for i in range(len(result[0])):
    if result[0][i][1] > temp:
        temp = result[0][i][1]
        topic = i

# %%
# Filter the result by query's corresponding topic category
# (Or it can be used as a weighted feature as well.)
df_same_topic = df[df['Topic Category'] == topic]
df_same_topic['Total Score'] = df_same_topic['Resource Score'] * 1.5 + df_same_topic['Recency Score'] * 1.5 + df_same_topic['Author Score'] * 0.5
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Display the searching result
df_same_topic.sort_values(by = 'Total Score', ascending = False)
# Out:
#         Date                                              Title  \
# 65   2019-06                                           Training
# 252  2019-03                                      Regional News
# 254  2019-03                                   Member Spotlight
# 20   2019-01                                        Safety Talk
# 228  2018-11                                        Safety Talk
# 15   2019-01                                          COPA News
# 17   2019-01                                 Cirrus Perspective
# 225  2018-11                                 Cirrus Perspective
# 222  2018-11                                 President's Column
# 362  2018-07                                      Regional News
# 90   2017-09                                        Safety Talk
# 74   2018-01                                   Member Spotlight
# 363  2018-07                                 Cirrus Perspective
# 86   2017-09                                      Regional News
# 169  2018-06                                 Cirrus Perspective
# 167  2018-06                                          COPA News
# 7    2015-01                                     Safety Feature
# 355  2017-06                                           Training
# 390  2017-01                                      Regional News
# 106  2016-09                                    Medical Musings
# 100  2016-09                                      Regional News
# 70   2018-01                                 President's Column
# 339  2006-07                                     Safety Feature
# 322  2016-05                                   Member Spotlight
# 306  2016-03                                      Regional News
# 284  2016-01                                    Medical Musings
# 87   2017-09                                 Cirrus Perspective
# 4    2015-01                                   Member Spotlight
# 404  2012-11                                      Regional News
# 391  2017-01                                 Cirrus Perspective
# ..       ...                                                ...
# 643  2014-05                                             Brakes
# 627  2014-05                                      LOP operation
# 663  2014-05                             Duluth Cirrus delivery
# 710  2014-05                                  Aileron gap seals
# 628  2014-05                       Low oil temperature solution
# 636  2014-05                                            Red fin
# 609  2014-05                             World's largest Cirrus
# 593  2014-05                                       Airsick kids
# 573  2014-05                                       Music volume
# 572  2014-05                                 GTX330 transponder
# 564  2014-05                              Circuit breaker panel
# 561  2014-05                              Arnav : download data
# 517  2014-05                            PTT Push to talk switch
# 624  2014-05                          Engine hot or warm starts
# 544  2014-05                      SR20 5 year hoses replacement
# 417  2018-09                                        Door Decals
# 422  2018-01       Spots of corrosion on elevator - where else?
# 431  2014-05                                         COPA forum
# 493  2014-05                                         COPA humor
# 432  2014-05                               COPA Pilots magazine
# 423  2016-04                                    Tires and Tubes
# 626  2015-04                      Lean Of Peak Engine Operation
# 480  2014-03                       Low aux audio volume problem
# 733  2018-12  CAPS Deployment Anomaly at Colorado Springs, C...
# 736  2018-10  ??That Sounds Expensive?? -- It Happened to ...
# 742  2014-11  Turning Fatals into CAPS Saves and Avoiding CA...
# 743  2014-11  Reviewing the causes of loss of engine power i...
# 746   2014-6  On CAPS deployments that landed in water -- ab...
# 753   2013-7  Cirrus Safety Milestone: Equal number of CAPS ...
# 762   2012-1  Early Reflections on CAPS Pull #32 by Dick McG...
#
#                                                Content           Author  \
# 65   JULY AUGUST 201954 COPA PilotSummer is here an...      TRIP TAYLOR
# 252  MARCH 201912 COPA Pilotwhere artists paint dra...   GIL WILLIAMSON
# 254  MARCH 201922 COPA PilotI know many of you have...     KIM BLONIGEN
# 20   JANUARY FEBRUARY 201940 COPA PilotThis unusual...       RICK BEACH
# 228  fl flThis column reects on an accident with my...       RICK BEACH
# 15   JANUARY FEBRUARY 20196 COPA PilotAttending soc...              NaN
# 17   JANUARY FEBRUARY 201918 COPA Pilotaircraft. I ...              NaN
# 225  Green Valley Ranch Resort and joined the fun. ...              NaN
# 222   flMigration 16 just wrapped up as I write thi...              NaN
# 362  JULY AUGUST 201812 COPA Pilotto ensure a safe ...   GIL WILLIAMSON
# 90   SEPTEMBER OCTOBER 201740 CIRRUS PILOTbug remov...       RICK BEACH
# 74   JANUARY FEBRUARY 201822 CIRRUS PILOTMay 30 Jun...     KIM BLONIGEN
# 363  JULY AUGUST 201818 COPA Pilotmy rst solo in th...              NaN
# 86   SEPTEMBER OCTOBER 201712 CIRRUS PILOTUpcoming ...   GIL WILLIAMSON
# 169  JUNE 201818 CIRRUS PILOTVolume 13 Number 5CIRR...              NaN
# 167  JUNE 20186 CIRRUS PILOTGuiding the direction o...              NaN
# 7    JANUARY FEBRUARY 201544CIRRUS PILOTby RICK BEA...       RICK BEACH
# 355  JUNE 201754 CIRRUS PILOTIn the quest to learn ...      TRIP TAYLOR
# 390  JANUARY FEBRUARY 201712CIRRUS PILOTcomfort zon...   GIL WILLIAMSON
# 106  SEPTEMBER OCTOBER 201652CIRRUS PILOTto our hol...  JERROLD SECKLER
# 100  SEPTEMBER OCTOBER 201612CIRRUS PILOTtraining a...   GIL WILLIAMSON
# 70   JANUARY FEBRUARY 20184 CIRRUS PILOTIts a new y...              NaN
# 339  I had decided that a fourandahalf hour night f...       RICK BEACH
# 322  MAY JUNE 201622CIRRUS PILOTrecord wasnt very g...     KIM BLONIGEN
# 306  MARCH APRIL 201612CIRRUS PILOTFleeing Cuba at ...   GIL WILLIAMSON
# 284  JANUARY FEBRUARY 201652CIRRUS PILOTin December...  JERROLD SECKLER
# 87   SEPTEMBER OCTOBER 201718 CIRRUS PILOTamount of...              NaN
# 4    JANUARY FEBRUARY 201522CIRRUS PILOTCirrus Pilo...     KIM BLONIGEN
# 404  November December 201212 CIRRUS PILOTsummer an...   GIL WILLIAMSON
# 391  JANUARY FEBRUARY 201718CIRRUS PILOTCirrus Pilo...              NaN
# ..                                                 ...              ...
# 643  Some Cirrus owners have experienced brake issu...   Roger Whittier
# 627  "NOTE: The specific fuel flow values listed be...   Roger Whittier
# 663  "When going to Duluth to pick up your plane, y...   Roger Whittier
# 710  Why gap seal?95% of a gap seal's benefit is fo...   Roger Whittier
# 628  As many of you have experienced also, we have ...   Roger Whittier
# 636  "The 'Red Fin' (aka Red Box) refers to that po...   Roger Whittier
# 609  This article is based on a COPA forum post.Sky...   Roger Whittier
# 593  There is such a thing as tolerance training. D...   Roger Whittier
# 573  The two audio input jacks on a Cirrus allow yo...   Roger Whittier
# 572  "The Garmin GTX330 transponder has a timer fac...   Roger Whittier
# 564  Here is a photo of a pre-PFD SR-22 (Serial #32...   Roger Whittier
# 561  ARNAV MFD : how to download EMM35 dataThe EMM3...   Roger Whittier
# 517  Member CommentsMy pilot-side PTT button is sta...   Roger Whittier
# 624  Starting procedure will depend on whether http...   Roger Whittier
# 544  12 Brake hoses8 at the master cylinders 1 each...   Roger Whittier
# 417  Looking for right side door stripe decals.As i...       Mark Craig
# 422  I've been watching a tiny (1/2") bump under th...        Jim Lewis
# 431  COPA forum image managementCOPA forums support...     Peter Storer
# 493  COPA humorThe COPA member forum has a traditio...     Peter Storer
# 432  This high quality magazine is chock full of ar...     Peter Storer
# 423  I notice there has not been much discussion ab...       John Evans
# 626  Lean Of PeakCan you run your engine Lean of Pe...      Steve Lucas
# 480  "Can I fix my audio volume problem?Actually, t...      John Ylinen
# 733  by RICK BEACH, COPA?? SAFETY CHAIR\nThis unusu...       Rick Beach
# 736  This column will appear in the Nov/Dec 2018 is...       Rick Beach
# 742  In a recent discussion of the survivable CAPS ...       Rick Beach
# 743  (updated with additional Probable Cause determ...       Rick Beach
# 746  Recently, a forum discussion on BeechTalk posi...       Rick Beach
# 753  The Cirrus community reached a significant saf...       Rick Beach
# 762  Dr. Richard ??Dick?? McGlaughlin and his dau...       Rick Beach
#
#      Resource  Topic Category  Resource Score  Recency Score  Author Score  \
# 65   Magazine               1             1.0       0.658009      0.217391
# 252  Magazine               1             1.0       0.430014      0.217391
# 254  Magazine               1             1.0       0.430014      0.217391
# 20   Magazine               1             1.0       0.347107      0.434783
# 228  Magazine               1             1.0       0.289710      0.434783
# 15   Magazine               1             1.0       0.347107      0.000000
# 17   Magazine               1             1.0       0.347107      0.000000
# 225  Magazine               1             1.0       0.289710      0.000000
# 222  Magazine               1             1.0       0.289710      0.000000
# 362  Magazine               1             1.0       0.215432      0.217391
# 90   Magazine               1             1.0       0.131868      0.434783
# 74   Magazine               1             1.0       0.152456      0.217391
# 363  Magazine               1             1.0       0.215432      0.000000
# 86   Magazine               1             1.0       0.131868      0.217391
# 169  Magazine               1             1.0       0.202020      0.000000
# 167  Magazine               1             1.0       0.202020      0.000000
# 7    Magazine               1             1.0       0.044783      0.434783
# 355  Magazine               1             1.0       0.115540      0.217391
# 390  Magazine               1             1.0       0.094729      0.217391
# 106  Magazine               1             1.0       0.082023      0.217391
# 100  Magazine               1             1.0       0.082023      0.217391
# 70   Magazine               1             1.0       0.152456      0.000000
# 339  Magazine               1             1.0       0.000000      0.434783
# 322  Magazine               1             1.0       0.071738      0.217391
# 306  Magazine               1             1.0       0.067296      0.217391
# 284  Magazine               1             1.0       0.063241      0.217391
# 87   Magazine               1             1.0       0.131868      0.000000
# 4    Magazine               1             1.0       0.044783      0.217391
# 404  Magazine               1             1.0       0.023471      0.217391
# 391  Magazine               1             1.0       0.094729      0.000000
# ..        ...             ...             ...            ...           ...
# 643      Wiki               1             0.5       0.036206      0.891304
# 627      Wiki               1             0.5       0.036206      0.891304
# 663      Wiki               1             0.5       0.036206      0.891304
# 710      Wiki               1             0.5       0.036206      0.891304
# 628      Wiki               1             0.5       0.036206      0.891304
# 636      Wiki               1             0.5       0.036206      0.891304
# 609      Wiki               1             0.5       0.036206      0.891304
# 593      Wiki               1             0.5       0.036206      0.891304
# 573      Wiki               1             0.5       0.036206      0.891304
# 572      Wiki               1             0.5       0.036206      0.891304
# 564      Wiki               1             0.5       0.036206      0.891304
# 561      Wiki               1             0.5       0.036206      0.891304
# 517      Wiki               1             0.5       0.036206      0.891304
# 624      Wiki               1             0.5       0.036206      0.891304
# 544      Wiki               1             0.5       0.036206      0.891304
# 417      Wiki               1             0.5       0.247619      0.007246
# 422      Wiki               1             0.5       0.152456      0.007246
# 431      Wiki               1             0.5       0.036206      0.210145
# 493      Wiki               1             0.5       0.036206      0.210145
# 432      Wiki               1             0.5       0.036206      0.210145
# 423      Wiki               1             0.5       0.069465      0.007246
# 626      Wiki               1             0.5       0.048642      0.028986
# 480      Wiki               1             0.5       0.034377      0.028986
# 733      Blog               1             0.0       0.316017      0.217391
# 736      Blog               1             0.0       0.267161      0.217391
# 742      Blog               1             0.0       0.042424      0.217391
# 743      Blog               1             0.0       0.042424      0.217391
# 746      Blog               1             0.0       0.037163      0.217391
# 753      Blog               1             0.0       0.028025      0.217391
# 762      Blog               1             0.0       0.018154      0.217391
#
#      Total Score
# 65      2.595709
# 252     2.253717
# 254     2.253717
# 20      2.238052
# 228     2.151957
# 15      2.020661
# 17      2.020661
# 225     1.934565
# 222     1.934565
# 362     1.931843
# 90      1.915194
# 74      1.837380
# 363     1.823147
# 86      1.806498
# 169     1.803030
# 167     1.803030
# 7       1.784566
# 355     1.782005
# 390     1.750789
# 106     1.731731
# 100     1.731731
# 70      1.728684
# 339     1.717391
# 322     1.716302
# 306     1.709640
# 284     1.703557
# 87      1.697802
# 4       1.675870
# 404     1.643901
# 391     1.642093
# ..           ...
# 643     1.249962
# 627     1.249962
# 663     1.249962
# 710     1.249962
# 628     1.249962
# 636     1.249962
# 609     1.249962
# 593     1.249962
# 573     1.249962
# 572     1.249962
# 564     1.249962
# 561     1.249962
# 517     1.249962
# 624     1.249962
# 544     1.249962
# 417     1.125052
# 422     0.982308
# 431     0.909382
# 493     0.909382
# 432     0.909382
# 423     0.857821
# 626     0.837456
# 480     0.816059
# 733     0.582722
# 736     0.509438
# 742     0.172332
# 743     0.172332
# 746     0.164440
# 753     0.150733
# 762     0.135926
#
# [102 rows x 10 columns]

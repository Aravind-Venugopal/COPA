# %% [markdown]
# # POC Model

# %% [markdown]
# __Install packages__

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import spacy
import glob
from datetime import datetime
import statistics
import math
import jmespath
import json

# %% [markdown]
# ### Converting Tree to JSON format

# %%
# Please run this code cell once only as multiple runs will affect the same file 
with open('Clean_mind_map.json') as json_file:
    data = json.load(json_file)
    
itemsKeyedById = {i["ID"]: i for i in data}

#iterate through each item in the `myJson` list.
for item in data[1:]:
    #does the item have a parent?
    if "Parent" in item:
        #get the parent item
        parent = itemsKeyedById[item['Parent']]
        #if the parent item doesn't have a "children" member, 
        #we must create one.
        if "children" not in parent:
            parent["children"] = []
        #add the item to its parent's "children" list.
        parent["children"].append(item)
topLevelItems = [item for item in data if "Parent" not in item]
data = {'data': data}

# %%
with open('data.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
data
# Out:
# {'data': [{'Title': 'COPA',
#    'Parent': None,
#    'ID': 1401320237,
#    'children': [{'Title': 'Lean of Peak',
#      'Parent': 1401320237,
#      'ID': 1401320426,
#      'children': [{'Title': 'LOP', 'Parent': 1401320426, 'ID': 1401322444},
#       {'Title': 'Mixture', 'Parent': 1401320426, 'ID': 1401322562},
#       {'Title': 'Red Box Table', 'Parent': 1401320426, 'ID': 1401322594},
#       {'Title': 'Red Fin', 'Parent': 1401320426, 'ID': 1401322652},
#       {'Title': 'WOTLOPSOP', 'Parent': 1401320426, 'ID': 1401322691},
#       {'Title': 'Cylinder Pressure', 'Parent': 1401320426, 'ID': 1401704789}]},
#     {'Title': 'Starter Issues',
#      'Parent': 1401320237,
#      'ID': 1401320499,
#      'children': [{'Title': 'Starter Adapter',
#        'Parent': 1401320499,
#        'ID': 1401705268},
#       {'Title': 'Starter Brands',
#        'Parent': 1401320499,
#        'ID': 1401705304,
#        'children': [{'Title': 'TCM', 'Parent': 1401705304, 'ID': 1401705907},
#         {'Title': 'Iskra', 'Parent': 1401705304, 'ID': 1401705951},
#         {'Title': 'Skytec', 'Parent': 1401705304, 'ID': 1401705993}]},
#       {'Title': 'Replacement', 'Parent': 1401320499, 'ID': 1401705540},
#       {'Title': 'Starter Maintenance', 'Parent': 1401320499, 'ID': 1401705712},
#       {'Title': 'Slipping', 'Parent': 1401320499, 'ID': 1401706029}]},
#     {'Title': 'Tires',
#      'Parent': 1401320237,
#      'ID': 1401320568,
#      'children': [{'Title': 'Tire Replacement',
#        'Parent': 1401320568,
#        'ID': 1401713807},
#       {'Title': 'Wheel Shaking', 'Parent': 1401320568, 'ID': 1401714087},
#       {'Title': 'Pressure', 'Parent': 1401320568, 'ID': 1401714219},
#       {'Title': 'Recommended Brands', 'Parent': 1401320568, 'ID': 1401714328},
#       {'Title': 'Flat Tires', 'Parent': 1401320568, 'ID': 1401714367},
#       {'Title': 'Tire Brands',
#        'Parent': 1401320568,
#        'ID': 1401714453,
#        'children': [{'Title': 'Goodyear',
#          'Parent': 1401714453,
#          'ID': 1401714502},
#         {'Title': 'Michelin', 'Parent': 1401714453, 'ID': 1401717048},
#         {'Title': 'Aero Classic', 'Parent': 1401714453, 'ID': 1401718385},
#         {'Title': 'STA', 'Parent': 1401714453, 'ID': 1401718406}]},
#       {'Title': 'Butyl Tubes', 'Parent': 1401320568, 'ID': 1401717219},
#       {'Title': 'Tire Shop',
#        'Parent': 1401320568,
#        'ID': 1401717389,
#        'children': [{'Title': 'Desser',
#          'Parent': 1401717389,
#          'ID': 1401717487}]},
#       {'Title': 'Tire Wear', 'Parent': 1401320568, 'ID': 1401717834},
#       {'Title': 'Tire Specifications', 'Parent': 1401320568, 'ID': 1401717876},
#       {'Title': 'Tire Wear Causes',
#        'Parent': 1401320568,
#        'ID': 1401717930,
#        'children': [{'Title': 'Skidding',
#          'Parent': 1401717930,
#          'ID': 1401717935}]},
#       {'Title': 'Retread', 'Parent': 1401320568, 'ID': 1401718110},
#       {'Title': 'Ply Rating', 'Parent': 1401320568, 'ID': 1401718789}]},
#     {'Title': 'Oil in the Belly',
#      'Parent': 1401320237,
#      'ID': 1401320609,
#      'children': [{'Title': 'Garfinkle extension',
#        'Parent': 1401320609,
#        'ID': 1401720749},
#       {'Title': 'Reduce oil', 'Parent': 1401320609, 'ID': 1401720794},
#       {'Title': 'Oil dipstick', 'Parent': 1401320609, 'ID': 1401721306},
#       {'Title': 'Air-oil separator', 'Parent': 1401320609, 'ID': 1401721372},
#       {'Title': 'Blow-by of combustion gases',
#        'Parent': 1401320609,
#        'ID': 1401721597},
#       {'Title': 'band-aid solutions',
#        'Parent': 1401320609,
#        'ID': 1401722356}]},
#     {'Title': 'Tugs',
#      'Parent': 1401320237,
#      'ID': 1401320667,
#      'children': [{'Title': 'Tow',
#        'Parent': 1401320667,
#        'ID': 1401728283,
#        'children': [{'Title': 'Aero-tow',
#          'Parent': 1401728283,
#          'ID': 1401728559,
#          'children': [{'Title': 'aero-tow e200 (electric)',
#            'Parent': 1401728559,
#            'ID': 1401729912},
#           {'Title': 'aero-tow lil sherman (electric)',
#            'Parent': 1401728559,
#            'ID': 1401730162}]},
#         {'Title': 'Power tow',
#          'Parent': 1401728283,
#          'ID': 1401728614,
#          'children': [{'Title': 'Power tow 40 EZ (gasoline)',
#            'Parent': 1401728614,
#            'ID': 1401730241},
#           {'Title': 'Power tow key ez (gasoline)',
#            'Parent': 1401728614,
#            'ID': 1401730346},
#           {'Title': 'Power tow 65 ez (gasoline)',
#            'Parent': 1401728614,
#            'ID': 1401730425},
#           {'Title': 'Power tow thundervolt (electric)',
#            'Parent': 1401728614,
#            'ID': 1401730480}]}]},
#       {'Title': 'Dragger',
#        'Parent': 1401320667,
#        'ID': 1401728928,
#        'children': [{'Title': 'Nose-Dragger Dragger',
#          'Parent': 1401728928,
#          'ID': 1401729102,
#          'children': [{'Title': 'Dragger Ndg (gasoline)',
#            'Parent': 1401729102,
#            'ID': 1401730684},
#           {'Title': 'Dragger nde-1 (electric)',
#            'Parent': 1401729102,
#            'ID': 1401730709}]},
#         {'Title': 'Tail-Dragger Dragger',
#          'Parent': 1401728928,
#          'ID': 1401729146,
#          'children': [{'Title': 'Dragger tdg-6 (gasoline)',
#            'Parent': 1401729146,
#            'ID': 1401730739},
#           {'Title': 'Dragger TDe-1 (electric)',
#            'Parent': 1401729146,
#            'ID': 1401730767}]}]},
#       {'Title': 'Airtug',
#        'Parent': 1401320667,
#        'ID': 1401729427,
#        'children': [{'Title': 'Airtug nfe-4 (electric)',
#          'Parent': 1401729427,
#          'ID': 1401730801},
#         {'Title': 'Airtug NFE-6 (electric)',
#          'Parent': 1401729427,
#          'ID': 1401730837}]},
#       {'Title': 'Priceless Aviation',
#        'Parent': 1401320667,
#        'ID': 1401729644,
#        'children': [{'Title': 'priceless 701E (electric)',
#          'Parent': 1401729644,
#          'ID': 1401730875},
#         {'Title': 'priceless 701EL (electric)',
#          'Parent': 1401729644,
#          'ID': 1401730891}]},
#       {'Title': 'Minimax',
#        'Parent': 1401320667,
#        'ID': 1401731030,
#        'children': [{'Title': 'minimax electric drill line',
#          'Parent': 1401731030,
#          'ID': 1401731084}]},
#       {'Title': 'Robotow',
#        'Parent': 1401320667,
#        'ID': 1401731114,
#        'children': [{'Title': 'Robotow 28vl (electric)',
#          'Parent': 1401731114,
#          'ID': 1401731360},
#         {'Title': 'robotow 24sl (electric)',
#          'Parent': 1401731114,
#          'ID': 1401731377},
#         {'Title': 'robotow Mooney 28vl (electric)',
#          'Parent': 1401731114,
#          'ID': 1401731396},
#         {'Title': 'Robotow Millenium (electric)',
#          'Parent': 1401731114,
#          'ID': 1401731411},
#         {'Title': 'robotwo lancair 28vl (electric)',
#          'Parent': 1401731114,
#          'ID': 1401731454}]},
#       {'Title': 'Battery life', 'Parent': 1401320667, 'ID': 1401728522},
#       {'Title': 'Tow Weight', 'Parent': 1401320667, 'ID': 1401731528},
#       {'Title': 'Engine', 'Parent': 1401320667, 'ID': 1401731560},
#       {'Title': 'Warranty', 'Parent': 1401320667, 'ID': 1401731586}]},
#     {'Title': 'Insurance',
#      'Parent': 1401320237,
#      'ID': 1401321072,
#      'children': [{'Title': 'Broker', 'Parent': 1401321072, 'ID': 1401732694},
#       {'Title': 'Policy', 'Parent': 1401321072, 'ID': 1401732810},
#       {'Title': 'Quote', 'Parent': 1401321072, 'ID': 1401733259},
#       {'Title': 'Claim', 'Parent': 1401321072, 'ID': 1401733659},
#       {'Title': 'Premium', 'Parent': 1401321072, 'ID': 1401734609},
#       {'Title': 'Accidents', 'Parent': 1401321072, 'ID': 1401735006},
#       {'Title': 'Liability', 'Parent': 1401321072, 'ID': 1401735238},
#       {'Title': 'Underwriter', 'Parent': 1401321072, 'ID': 1401735267},
#       {'Title': 'Company',
#        'Parent': 1401321072,
#        'ID': 1401736409,
#        'children': [{'Title': 'Wings Insurance',
#          'Parent': 1401736409,
#          'ID': 1401736468},
#         {'Title': 'Aviation Insurance Resources',
#          'Parent': 1401736409,
#          'ID': 1401736498},
#         {'Title': 'AVEMCO', 'Parent': 1401736409, 'ID': 1401736667}]}]},
#     {'Title': 'CAPS',
#      'Parent': 1401320237,
#      'ID': 1401321126,
#      'children': [{'Title': 'Fetal accidents',
#        'Parent': 1401321126,
#        'ID': 1401743613},
#       {'Title': 'Safety', 'Parent': 1401321126, 'ID': 1401743645},
#       {'Title': 'Cirrus Airframe Parachute System',
#        'Parent': 1401321126,
#        'ID': 1401743733},
#       {'Title': 'Parachute', 'Parent': 1401321126, 'ID': 1401744071},
#       {'Title': 'Rocket', 'Parent': 1401321126, 'ID': 1401744118},
#       {'Title': 'repack', 'Parent': 1401321126, 'ID': 1401744656},
#       {'Title': 'chute', 'Parent': 1401321126, 'ID': 1401745238},
#       {'Title': 'Deployment Sequence',
#        'Parent': 1401321126,
#        'ID': 1401747148,
#        'children': [{'Title': 'CAPS Activation',
#          'Parent': 1401747148,
#          'ID': 1401747181},
#         {'Title': 'Rocket and Parachute Extraction',
#          'Parent': 1401747148,
#          'ID': 1401747207},
#         {'Title': 'Line Extension', 'Parent': 1401747148, 'ID': 1401747269},
#         {'Title': 'Initial Canopy Inflation',
#          'Parent': 1401747148,
#          'ID': 1401747627},
#         {'Title': 'Reefed Parachute', 'Parent': 1401747148, 'ID': 1401747667},
#         {'Title': 'Parachute Disreef', 'Parent': 1401747148, 'ID': 1401747224},
#         {'Title': 'Snub Line Release', 'Parent': 1401747148, 'ID': 1401747483},
#         {'Title': 'Touchdown', 'Parent': 1401747148, 'ID': 1401747706}]},
#       {'Title': 'Demonstrated Deployment Parameters',
#        'Parent': 1401321126,
#        'ID': 1401747761,
#        'children': [{'Title': '400â€™ (561â€™ G5*)',
#          'Parent': 1401747761,
#          'ID': 1401747778},
#         {'Title': '920â€™ (1081â€™ G5*)',
#          'Parent': 1401747761,
#          'ID': 1401747790},
#         {'Title': '135 KIAS - VPD (SR20 G1/G2)',
#          'Parent': 1401747761,
#          'ID': 1401747850},
#         {'Title': '133 KIAS - VPD (SR20 G3/SR22/SR22T)',
#          'Parent': 1401747761,
#          'ID': 1401747868},
#         {'Title': '140 KIAS - VPD (SR22/SR22TG5)',
#          'Parent': 1401747761,
#          'ID': 1401747923}]},
#       {'Title': 'Possible CAPS Deployment Situations',
#        'Parent': 1401321126,
#        'ID': 1401748031,
#        'children': [{'Title': 'Loss of Control',
#          'Parent': 1401748031,
#          'ID': 1401748065},
#         {'Title': 'Engine Failure',
#          'Parent': 1401748031,
#          'ID': 1401748104,
#          'children': [{'Title': 'Not Over a Runaway',
#            'Parent': 1401748104,
#            'ID': 1401748905},
#           {'Title': 'Over a Runaway',
#            'Parent': 1401748104,
#            'ID': 1401749017}]},
#         {'Title': 'Pilot Incapacitation',
#          'Parent': 1401748031,
#          'ID': 1401748130},
#         {'Title': 'Mid-Air Collision', 'Parent': 1401748031, 'ID': 1401748151},
#         {'Title': 'Structural Failure',
#          'Parent': 1401748031,
#          'ID': 1401748167}]},
#       {'Title': 'Altitude', 'Parent': 1401321126, 'ID': 1401748229},
#       {'Title': 'Speed', 'Parent': 1401321126, 'ID': 1401748239}]},
#     {'Title': 'Weather Tools and Websites',
#      'Parent': 1401320237,
#      'ID': 1401321167,
#      'children': [{'Title': 'Aviation Weather Report and Forecast',
#        'Parent': 1401321167,
#        'ID': 1403875660},
#       {'Title': 'hourly weather', 'Parent': 1401321167, 'ID': 1403877893},
#       {'Title': 'COW',
#        'Parent': 1401321167,
#        'ID': 1403897553,
#        'children': [{'Title': 'Cowardly Obviating Weather',
#          'Parent': 1403897553,
#          'ID': 1403897572}]},
#       {'Title': 'MAG',
#        'Parent': 1401321167,
#        'ID': 1403897583,
#        'children': [{'Title': 'Model Analysis and Guidance',
#          'Parent': 1403897583,
#          'ID': 1403897598}]},
#       {'Title': 'forecast', 'Parent': 1401321167, 'ID': 1403897833},
#       {'Title': 'simulated radar', 'Parent': 1401321167, 'ID': 1403898013},
#       {'Title': 'NAM',
#        'Parent': 1401321167,
#        'ID': 1403898084,
#        'children': [{'Title': 'North American Mesoscale Model',
#          'Parent': 1403898084,
#          'ID': 1403898121}]}]},
#     {'Title': 'XM Weather',
#      'Parent': 1401320237,
#      'ID': 1401321305,
#      'children': [{'Title': 'XM Weather Aviation package',
#        'Parent': 1401321305,
#        'ID': 1403781785},
#       {'Title': 'Radar', 'Parent': 1401321305, 'ID': 1403783685},
#       {'Title': 'Precipitation Type (at surface)',
#        'Parent': 1401321305,
#        'ID': 1403783895},
#       {'Title': 'City Forecasts', 'Parent': 1401321305, 'ID': 1403783917},
#       {'Title': 'TFRs', 'Parent': 1401321305, 'ID': 1403783996},
#       {'Title': 'METARs', 'Parent': 1401321305, 'ID': 1403783998},
#       {'Title': 'TAFs', 'Parent': 1401321305, 'ID': 1403784011},
#       {'Title': 'Warnings', 'Parent': 1401321305, 'ID': 1403784012},
#       {'Title': 'Lightning', 'Parent': 1401321305, 'ID': 1403784058},
#       {'Title': 'AIRMETs', 'Parent': 1401321305, 'ID': 1403784070},
#       {'Title': 'SIGMETs', 'Parent': 1401321305, 'ID': 1403784178},
#       {'Title': 'Echo Tops', 'Parent': 1401321305, 'ID': 1403784231},
#       {'Title': 'Freezing Level', 'Parent': 1401321305, 'ID': 1403784449},
#       {'Title': 'Severe Weather Storm Tracks',
#        'Parent': 1401321305,
#        'ID': 1403784461},
#       {'Title': 'Surface Analysis', 'Parent': 1401321305, 'ID': 1403784463},
#       {'Title': 'Satellite Mosaic', 'Parent': 1401321305, 'ID': 1403784464},
#       {'Title': 'AIREPs', 'Parent': 1401321305, 'ID': 1403784465},
#       {'Title': 'PIREPs', 'Parent': 1401321305, 'ID': 1403784466},
#       {'Title': 'SPC Aviation Weather Watches',
#        'Parent': 1401321305,
#        'ID': 1403784477},
#       {'Title': 'Turbulence', 'Parent': 1401321305, 'ID': 1403784484},
#       {'Title': 'CIP', 'Parent': 1401321305, 'ID': 1403784776},
#       {'Title': 'SLD', 'Parent': 1401321305, 'ID': 1403784783},
#       {'Title': 'SPC', 'Parent': 1401321305, 'ID': 1403784814},
#       {'Title': 'Visibility', 'Parent': 1401321305, 'ID': 1403784836},
#       {'Title': 'Hurricane Track', 'Parent': 1401321305, 'ID': 1403784875}]},
#     {'Title': 'Airspeeds for Safe Operations',
#      'Parent': 1401320237,
#      'ID': 1401321371,
#      'children': [{'Title': 'VNE', 'Parent': 1401321371, 'ID': 1403791053},
#       {'Title': 'ASI',
#        'Parent': 1401321371,
#        'ID': 1403791244,
#        'children': [{'Title': 'airspeed indicator',
#          'Parent': 1403791244,
#          'ID': 1403792214}]},
#       {'Title': 'mph', 'Parent': 1401321371, 'ID': 1403791274},
#       {'Title': 'knots', 'Parent': 1401321371, 'ID': 1403791292},
#       {'Title': 'CAS',
#        'Parent': 1401321371,
#        'ID': 1403791377,
#        'children': [{'Title': 'Calibrated airspeed',
#          'Parent': 1403791377,
#          'ID': 1403792310}]},
#       {'Title': 'TAS',
#        'Parent': 1401321371,
#        'ID': 1403791404,
#        'children': [{'Title': 'True airspeed',
#          'Parent': 1403791404,
#          'ID': 1403792346}]},
#       {'Title': 'VFE', 'Parent': 1401321371, 'ID': 1403791515},
#       {'Title': 'CG',
#        'Parent': 1401321371,
#        'ID': 1403792477,
#        'children': [{'Title': 'center of gravity',
#          'Parent': 1403792477,
#          'ID': 1403792501}]},
#       {'Title': 'V-speeds',
#        'Parent': 1401321371,
#        'ID': 1403791795,
#        'children': [{'Title': 'weight',
#          'Parent': 1403791795,
#          'ID': 1403792001},
#         {'Title': 'configuration', 'Parent': 1403791795, 'ID': 1403792033},
#         {'Title': 'configuration', 'Parent': 1403791795, 'ID': 1403792055}]}]},
#     {'Title': 'Hot Starts',
#      'Parent': 1401320237,
#      'ID': 1401321412,
#      'children': [{'Title': 'turbine based engines',
#        'Parent': 1401321412,
#        'ID': 1402313823},
#       {'Title': 'reciprocating fuel injected engines',
#        'Parent': 1401321412,
#        'ID': 1402313928},
#       {'Title': 'FADEC', 'Parent': 1401321412, 'ID': 1402315389}]},
#     {'Title': 'Icing',
#      'Parent': 1401320237,
#      'ID': 1401321443,
#      'children': [{'Title': 'Structural Ice',
#        'Parent': 1401321443,
#        'ID': 1404392681},
#       {'Title': 'Wing Stall', 'Parent': 1401321443, 'ID': 1404392710},
#       {'Title': 'Tail Stall', 'Parent': 1401321443, 'ID': 1404392770},
#       {'Title': 'Roll Control', 'Parent': 1401321443, 'ID': 1404392834},
#       {'Title': 'Anti-Icing &amp; Deicing',
#        'Parent': 1401321443,
#        'ID': 1404393537,
#        'children': [{'Title': 'Propeller',
#          'Parent': 1404393537,
#          'ID': 1404393987},
#         {'Title': 'Wing', 'Parent': 1404393537, 'ID': 1404394229},
#         {'Title': 'Windshield', 'Parent': 1404393537, 'ID': 1404394423},
#         {'Title': 'Carburetor Heat', 'Parent': 1404393537, 'ID': 1404394508}]},
#       {'Title': 'Effects',
#        'Parent': 1401321443,
#        'ID': 1404395938,
#        'children': [{'Title': 'Adverse Aerodynamic',
#          'Parent': 1404395938,
#          'ID': 1404395983},
#         {'Title': 'Blockage of pitot tubes and static vents',
#          'Parent': 1404395938,
#          'ID': 1404396093},
#         {'Title': 'Radio communication',
#          'Parent': 1404395938,
#          'ID': 1404396262},
#         {'Title': 'Surface Hazard', 'Parent': 1404395938, 'ID': 1404396295}]},
#       {'Title': 'Ice accretion',
#        'Parent': 1401321443,
#        'ID': 1404396553,
#        'children': [{'Title': 'Rime Ice',
#          'Parent': 1404396553,
#          'ID': 1404396592},
#         {'Title': 'Clear Ice', 'Parent': 1404396553, 'ID': 1404396641},
#         {'Title': 'Cloudy or Mixed Ice',
#          'Parent': 1404396553,
#          'ID': 1404396673},
#         {'Title': 'Supercooled Large Droplets (SLD)',
#          'Parent': 1404396553,
#          'ID': 1404396842},
#         {'Title': 'Runback Ice', 'Parent': 1404396553, 'ID': 1404396918},
#         {'Title': 'Intercycle Ice',
#          'Parent': 1404396553,
#          'ID': 1404397006}]}]},
#     {'Title': 'Battery Issues',
#      'Parent': 1401320237,
#      'ID': 1401320528,
#      'children': [{'Title': 'Voltage',
#        'Parent': 1401320528,
#        'ID': 1401707140,
#        'children': [{'Title': 'Low Voltage',
#          'Parent': 1401707140,
#          'ID': 1401707164},
#         {'Title': 'High Voltage', 'Parent': 1401707140, 'ID': 1401707184}]},
#       {'Title': 'MCU', 'Parent': 1401320528, 'ID': 1401707239},
#       {'Title': 'Alternator Failure',
#        'Parent': 1401320528,
#        'ID': 1401707417,
#        'children': [{'Title': 'Full Battery Discharge',
#          'Parent': 1401707417,
#          'ID': 1401707544}]},
#       {'Title': 'Failed Battery', 'Parent': 1401320528, 'ID': 1401707510},
#       {'Title': 'ALT 1 Voltage', 'Parent': 1401320528, 'ID': 1401707572},
#       {'Title': 'Main Bus Drop', 'Parent': 1401320528, 'ID': 1401708081}]},
#     {'Title': 'Oxygen System',
#      'Parent': 1401320237,
#      'ID': 1401320546,
#      'children': [{'Title': 'O2', 'Parent': 1401320546, 'ID': 1401322473},
#       {'Title': 'Gaseous aviatorâ€™s breathing oxygen',
#        'Parent': 1401320546,
#        'ID': 1401323023,
#        'children': [{'Title': 'ABO', 'Parent': 1401323023, 'ID': 1401323042}]},
#       {'Title': 'LOX',
#        'Parent': 1401320546,
#        'ID': 1401708351,
#        'children': [{'Title': 'Liquid aviators breathing oxygen',
#          'Parent': 1401708351,
#          'ID': 1401708372}]},
#       {'Title': 'MSOG',
#        'Parent': 1401320546,
#        'ID': 1401708420,
#        'children': [{'Title': 'Molecular sieve oxygen generators',
#          'Parent': 1401708420,
#          'ID': 1401708571}]},
#       {'Title': 'Delivery Systems',
#        'Parent': 1401320546,
#        'ID': 1401708612,
#        'children': [{'Title': 'Continuous Flow',
#          'Parent': 1401708612,
#          'ID': 1401708628},
#         {'Title': 'Diluter Demand', 'Parent': 1401708612, 'ID': 1401708655},
#         {'Title': 'Pressure Demand', 'Parent': 1401708612, 'ID': 1401708678}]},
#       {'Title': 'Masks and Cannulas',
#        'Parent': 1401320546,
#        'ID': 1401708717,
#        'children': [{'Title': 'Nasal Cannulas',
#          'Parent': 1401708717,
#          'ID': 1401708752},
#         {'Title': 'Oral-nasal re-breather',
#          'Parent': 1401708717,
#          'ID': 1401708773},
#         {'Title': 'Quick-don mask', 'Parent': 1401708717, 'ID': 1401708794},
#         {'Title': 'Airline drop-down units',
#          'Parent': 1401708717,
#          'ID': 1401708835},
#         {'Title': 'Dixie Cup', 'Parent': 1401708717, 'ID': 1401708894}]},
#       {'Title': 'PRICE Check',
#        'Parent': 1401320546,
#        'ID': 1401709052,
#        'children': [{'Title': 'Pressure',
#          'Parent': 1401709052,
#          'ID': 1401709064},
#         {'Title': 'Regulator', 'Parent': 1401709052, 'ID': 1401709108},
#         {'Title': 'Indicator', 'Parent': 1401709052, 'ID': 1401709126},
#         {'Title': 'Connections', 'Parent': 1401709052, 'ID': 1401709172},
#         {'Title': 'Emergency', 'Parent': 1401709052, 'ID': 1401709216}]},
#       {'Title': 'Training', 'Parent': 1401320546, 'ID': 1401709273},
#       {'Title': 'Part 135 Requirement',
#        'Parent': 1401320546,
#        'ID': 1401709305},
#       {'Title': 'Part 91 Requirements',
#        'Parent': 1401320546,
#        'ID': 1401709350}]},
#     {'Title': 'Alternator Issues',
#      'Parent': 1401320237,
#      'ID': 1401320558,
#      'children': [{'Title': 'Low Output',
#        'Parent': 1401320558,
#        'ID': 1401709433},
#       {'Title': 'Voltages', 'Parent': 1401320558, 'ID': 1401709491},
#       {'Title': 'Electrical System', 'Parent': 1401320558, 'ID': 1401709621},
#       {'Title': 'Avidyne System', 'Parent': 1401320558, 'ID': 1401709643},
#       {'Title': 'Troubleshooting', 'Parent': 1401320558, 'ID': 1401709719},
#       {'Title': 'Wire Chaffing', 'Parent': 1401320558, 'ID': 1401713122},
#       {'Title': 'Magnetism', 'Parent': 1401320558, 'ID': 1401713290},
#       {'Title': 'Battery Changes', 'Parent': 1401320558, 'ID': 1401713759}]},
#     {'Title': 'Brakes',
#      'Parent': 1401320237,
#      'ID': 1401320598,
#      'children': [{'Title': 'Brake assembly',
#        'Parent': 1401320598,
#        'ID': 1401718862},
#       {'Title': 'Dual Caliper Brake', 'Parent': 1401320598, 'ID': 1401718974},
#       {'Title': 'Speed Brakes', 'Parent': 1401320598, 'ID': 1401719250},
#       {'Title': 'Brake Linings', 'Parent': 1401320598, 'ID': 1401719532},
#       {'Title': 'Brake Pads', 'Parent': 1401320598, 'ID': 1401719733},
#       {'Title': 'Brake Fluid', 'Parent': 1401320598, 'ID': 1401719805},
#       {'Title': 'Maintenance', 'Parent': 1401320598, 'ID': 1401719868},
#       {'Title': 'Brake Pedals', 'Parent': 1401320598, 'ID': 1401720159}]},
#     {'Title': 'Cleaning Screens',
#      'Parent': 1401320237,
#      'ID': 1401320637,
#      'children': [{'Title': 'Cleaning Products',
#        'Parent': 1401320637,
#        'ID': 1401724267},
#       {'Title': 'PFD Screens', 'Parent': 1401320637, 'ID': 1401724474},
#       {'Title': 'MFD Screens', 'Parent': 1401320637, 'ID': 1401724508},
#       {'Title': 'Screen Protector', 'Parent': 1401320637, 'ID': 1401725075},
#       {'Title': 'Deionized Water', 'Parent': 1401320637, 'ID': 1401725400},
#       {'Title': 'Micro Towels', 'Parent': 1401320637, 'ID': 1401725513}]},
#     {'Title': 'Turbo vs Normally Aspirated',
#      'Parent': 1401320237,
#      'ID': 1401321114,
#      'children': [{'Title': 'Turbocharged Engine',
#        'Parent': 1401321114,
#        'ID': 1401737511,
#        'children': [{'Title': 'Small', 'Parent': 1401737511, 'ID': 1401740765},
#         {'Title': 'Efficient', 'Parent': 1401737511, 'ID': 1401740993},
#         {'Title': 'Lag', 'Parent': 1401737511, 'ID': 1401741299},
#         {'Title': 'Turbo', 'Parent': 1401737511, 'ID': 1401741716},
#         {'Title': 'Nose heavy', 'Parent': 1401737511, 'ID': 1401742151},
#         {'Title': 'T', 'Parent': 1401737511, 'ID': 1401742553},
#         {'Title': 'Turbo exhaust', 'Parent': 1401737511, 'ID': 1401742777}]},
#       {'Title': 'Normally Aspirated Engine',
#        'Parent': 1401321114,
#        'ID': 1401737576,
#        'children': [{'Title': 'low-end power',
#          'Parent': 1401737576,
#          'ID': 1401741372},
#         {'Title': 'NA', 'Parent': 1401737576, 'ID': 1401741693},
#         {'Title': 'Mountain', 'Parent': 1401737576, 'ID': 1401743165}]},
#       {'Title': 'Combustion chamber', 'Parent': 1401321114, 'ID': 1401740190},
#       {'Title': 'Turbine', 'Parent': 1401321114, 'ID': 1401740297},
#       {'Title': 'Pump', 'Parent': 1401321114, 'ID': 1401741017},
#       {'Title': 'Gearing', 'Parent': 1401321114, 'ID': 1401741112},
#       {'Title': 'Throttle', 'Parent': 1401321114, 'ID': 1401741153},
#       {'Title': 'AOG time', 'Parent': 1401321114, 'ID': 1401742009},
#       {'Title': 'Maintenance', 'Parent': 1401321114, 'ID': 1401742454},
#       {'Title': 'Chute', 'Parent': 1401321114, 'ID': 1401742937}]},
#     {'Title': 'Personal Minimums',
#      'Parent': 1401320237,
#      'ID': 1401321143,
#      'children': [{'Title': 'Safety', 'Parent': 1401321143, 'ID': 1401768092},
#       {'Title': 'Loss of Control', 'Parent': 1401321143, 'ID': 1401768344},
#       {'Title': 'PAVE',
#        'Parent': 1401321143,
#        'ID': 1401768824,
#        'children': [{'Title': 'Pilot',
#          'Parent': 1401768824,
#          'ID': 1401768841,
#          'children': [{'Title': 'Experience',
#            'Parent': 1401768841,
#            'ID': 1401769556},
#           {'Title': 'Recency', 'Parent': 1401768841, 'ID': 1401769581},
#           {'Title': 'Physical Condition',
#            'Parent': 1401768841,
#            'ID': 1401769621}]},
#         {'Title': 'Aircraft',
#          'Parent': 1401768824,
#          'ID': 1401768850,
#          'children': [{'Title': 'Fuel Reserves',
#            'Parent': 1401768850,
#            'ID': 1401769660},
#           {'Title': 'Experience in type',
#            'Parent': 1401768850,
#            'ID': 1401769835},
#           {'Title': 'Aircraft Performance',
#            'Parent': 1401768850,
#            'ID': 1401769884},
#           {'Title': 'Aircraft Equipment',
#            'Parent': 1401768850,
#            'ID': 1401770158}]},
#         {'Title': 'Environment',
#          'Parent': 1401768824,
#          'ID': 1401768884,
#          'children': [{'Title': 'Airport Condition',
#            'Parent': 1401768884,
#            'ID': 1401770257},
#           {'Title': 'Weather', 'Parent': 1401768884, 'ID': 1401770270},
#           {'Title': 'Weather for VFR', 'Parent': 1401768884, 'ID': 1401770290},
#           {'Title': 'Weather for IFR',
#            'Parent': 1401768884,
#            'ID': 1401770335}]},
#         {'Title': 'External pressures',
#          'Parent': 1401768824,
#          'ID': 1401768953}]},
#       {'Title': 'Checklist', 'Parent': 1401321143, 'ID': 1401769232},
#       {'Title': 'National Airspace System',
#        'Parent': 1401321143,
#        'ID': 1401770563},
#       {'Title': 'VFR', 'Parent': 1401321143, 'ID': 1401770581},
#       {'Title': 'IFR', 'Parent': 1401321143, 'ID': 1401770586}]},
#     {'Title': 'Magneto Issues',
#      'Parent': 1401320237,
#      'ID': 1401321220,
#      'children': [{'Title': 'Capacitor',
#        'Parent': 1401321220,
#        'ID': 1401774377,
#        'children': [{'Title': 'dielectric degradation',
#          'Parent': 1401774377,
#          'ID': 1401774568},
#         {'Title': 'conductor breakage',
#          'Parent': 1401774377,
#          'ID': 1401774593}]},
#       {'Title': 'Coil Failure', 'Parent': 1401321220, 'ID': 1401774397},
#       {'Title': 'Contact Points', 'Parent': 1401321220, 'ID': 1401774411},
#       {'Title': 'Service', 'Parent': 1401321220, 'ID': 1401775369}]},
#     {'Title': 'ADS-B',
#      'Parent': 1401320237,
#      'ID': 1401321328,
#      'children': [{'Title': 'Automatic Dependent\rSurveillance-Broadcast',
#        'Parent': 1401321328,
#        'ID': 1403786536},
#       {'Title': 'ADS-B Out', 'Parent': 1401321328, 'ID': 1403786628},
#       {'Title': 'ADS-B IN', 'Parent': 1401321328, 'ID': 1403788285},
#       {'Title': 'GPS', 'Parent': 1401321328, 'ID': 1403788012},
#       {'Title': 'ground stations', 'Parent': 1401321328, 'ID': 1403788071},
#       {'Title': 'ADS-B rule airspace',
#        'Parent': 1401321328,
#        'ID': 1403788165}]},
#     {'Title': 'Training',
#      'Parent': 1401320237,
#      'ID': 1401321390,
#      'children': [{'Title': 'instrument',
#        'Parent': 1401321390,
#        'ID': 1403862559},
#       {'Title': 'transition', 'Parent': 1401321390, 'ID': 1403862585},
#       {'Title': 'CSIP', 'Parent': 1401321390, 'ID': 1403863115},
#       {'Title': 'instructors', 'Parent': 1401321390, 'ID': 1403863307},
#       {'Title': 'COPA University', 'Parent': 1401321390, 'ID': 1403864069},
#       {'Title': 'accident', 'Parent': 1401321390, 'ID': 1403865155},
#       {'Title': 'safety', 'Parent': 1401321390, 'ID': 1403865291},
#       {'Title': 'Cirrus Approach', 'Parent': 1401321390, 'ID': 1403865721},
#       {'Title': 'CAPS', 'Parent': 1401321390, 'ID': 1403865749}]},
#     {'Title': 'Flying Approaches',
#      'Parent': 1401320237,
#      'ID': 1401321437,
#      'children': [{'Title': 'precision approach (PA)',
#        'Parent': 1401321437,
#        'ID': 1402265888,
#        'children': [{'Title': 'Ground controlled approach (GCA)',
#          'Parent': 1402265888,
#          'ID': 1402267914},
#         {'Title': 'GBAS landing system (GLS)',
#          'Parent': 1402265888,
#          'ID': 1402268177},
#         {'Title': 'Instrument landing system (ILS)',
#          'Parent': 1402265888,
#          'ID': 1402268211},
#         {'Title': 'Joint Precision Approach and Landing\rSystem (JPALS)',
#          'Parent': 1402265888,
#          'ID': 1402268254},
#         {'Title': 'Microwave landing system (MLS)',
#          'Parent': 1402265888,
#          'ID': 1402268297},
#         {'Title': 'Precision approach radar (PAR)',
#          'Parent': 1402265888,
#          'ID': 1402268324},
#         {'Title': 'Transponder landing system (TLS)',
#          'Parent': 1402265888,
#          'ID': 1402268391}]},
#       {'Title': 'approach with vertical guidance (APV)',
#        'Parent': 1401321437,
#        'ID': 1402266005},
#       {'Title': 'non-precision approach (NPA)',
#        'Parent': 1401321437,
#        'ID': 1402266040,
#        'children': [{'Title': 'VHF omnidirectional range (VOR)',
#          'Parent': 1402266040,
#          'ID': 1402266597},
#         {'Title': 'Tactical air navigation (TACAN)',
#          'Parent': 1402266040,
#          'ID': 1402266642},
#         {'Title': 'Non-directional beacon (NDB)',
#          'Parent': 1402266040,
#          'ID': 1402266672},
#         {'Title': 'Simplified directional facility (SDF)',
#          'Parent': 1402266040,
#          'ID': 1402266702},
#         {'Title': 'LNAV/VNAV approaches',
#          'Parent': 1402266040,
#          'ID': 1402267313},
#         {'Title': 'Required navigation performance (RNP)',
#          'Parent': 1402266040,
#          'ID': 1402267420},
#         {'Title': 'Localizer', 'Parent': 1402266040, 'ID': 1402267449},
#         {'Title': 'Localizer type directional aid (LDA)',
#          'Parent': 1402266040,
#          'ID': 1402267783},
#         {'Title': 'Surveillance radar approach (SRA)',
#          'Parent': 1402266040,
#          'ID': 1402267819},
#         {'Title': 'Airport surveillance radar (ASR)',
#          'Parent': 1402266040,
#          'ID': 1402267878}]}]},
#     {'Title': 'Cylinder Issues',
#      'Parent': 1401320237,
#      'ID': 1401321456,
#      'children': [{'Title': 'Cracks', 'Parent': 1401321456, 'ID': 1404415696},
#       {'Title': 'Valve Failures', 'Parent': 1401321456, 'ID': 1404415808},
#       {'Title': 'Head/Barrel Separation',
#        'Parent': 1401321456,
#        'ID': 1404415834},
#       {'Title': 'Parts',
#        'Parent': 1401321456,
#        'ID': 1404416133,
#        'children': [{'Title': 'Valve', 'Parent': 1404416133, 'ID': 1404416207},
#         {'Title': 'Exhaust Port', 'Parent': 1404416133, 'ID': 1404416349},
#         {'Title': 'Cylinder Head', 'Parent': 1404416133, 'ID': 1404416409},
#         {'Title': 'Cylinder barrel', 'Parent': 1404416133, 'ID': 1404416503},
#         {'Title': 'Intake port', 'Parent': 1404416133, 'ID': 1404416576},
#         {'Title': 'Spark plug port', 'Parent': 1404416133, 'ID': 1404416631},
#         {'Title': 'Fuel injector port',
#          'Parent': 1404416133,
#          'ID': 1404416731},
#         {'Title': 'Mounting base', 'Parent': 1404416133, 'ID': 1404416831}]}]},
#     {'Title': 'Autopilot Issues',
#      'Parent': 1401320237,
#      'ID': 1401321476,
#      'children': [{'Title': 'AP', 'Parent': 1401321476, 'ID': 1401727898},
#       {'Title': 'S-TEC',
#        'Parent': 1401321476,
#        'ID': 1401734708,
#        'children': [{'Title': 'Modes of Operation',
#          'Parent': 1401734708,
#          'ID': 1401889312,
#          'children': [{'Title': 'Roll Axis Control',
#            'Parent': 1401889312,
#            'ID': 1401889562},
#           {'Title': 'Pitch Axis Control',
#            'Parent': 1401889312,
#            'ID': 1401889634}]},
#         {'Title': 'Pre-Flight Procedures',
#          'Parent': 1401734708,
#          'ID': 1401889713,
#          'children': [{'Title': 'Power-Up Test',
#            'Parent': 1401889713,
#            'ID': 1401889771},
#           {'Title': 'Pre-Flight Test',
#            'Parent': 1401889713,
#            'ID': 1401889854}]},
#         {'Title': 'In-Flight Procedures',
#          'Parent': 1401734708,
#          'ID': 1401889918,
#          'children': [{'Title': 'Normal Operating Procedures',
#            'Parent': 1401889918,
#            'ID': 1401890207,
#            'children': [{'Title': 'Heading (HDG) Mode.',
#              'Parent': 1401890207,
#              'ID': 1401890303},
#             {'Title': 'Navigation (NAV) Mode',
#              'Parent': 1401890207,
#              'ID': 1401890377},
#             {'Title': 'Global Positioning System Steering (GPSS)\rMode',
#              'Parent': 1401890207,
#              'ID': 1401890439},
#             {'Title': 'Altitude Hold (ALT) Mode',
#              'Parent': 1401890207,
#              'ID': 1401890470},
#             {'Title': 'Altitude Hold (ALT) Mode',
#              'Parent': 1401890207,
#              'ID': 1401890523},
#             {'Title': 'Altitude Pre-Select Function',
#              'Parent': 1401890207,
#              'ID': 1401890615},
#             {'Title': 'Autotrim', 'Parent': 1401890207, 'ID': 1401890785},
#             {'Title': 'Manual Electric Trim',
#              'Parent': 1401890207,
#              'ID': 1401890893}]},
#           {'Title': 'Precision Approach Procedures',
#            'Parent': 1401889918,
#            'ID': 1401891103,
#            'children': [{'Title': 'Straight-In ILS Approach',
#              'Parent': 1401891103,
#              'ID': 1401891323},
#             {'Title': 'ILS Approach',
#              'Parent': 1401891103,
#              'ID': 1401891373}]},
#           {'Title': 'Non-Precision Approach Procedures',
#            'Parent': 1401889918,
#            'ID': 1401892233,
#            'children': [{'Title': 'Straight-In Back Course Approach',
#              'Parent': 1401892233,
#              'ID': 1401892354},
#             {'Title': 'Back Course Approach',
#              'Parent': 1401892233,
#              'ID': 1401892646},
#             {'Title': 'Straight-In LOC Approach',
#              'Parent': 1401892233,
#              'ID': 1401892692},
#             {'Title': 'Straight-In VOR Approach',
#              'Parent': 1401892233,
#              'ID': 1401892753},
#             {'Title': 'LOC Approach', 'Parent': 1401892233, 'ID': 1401892810},
#             {'Title': 'GPSS Approach',
#              'Parent': 1401892233,
#              'ID': 1401893777}]},
#           {'Title': 'Flight Director (FD) Operation',
#            'Parent': 1401889918,
#            'ID': 1401893918,
#            'children': [{'Title': 'AP Mode',
#              'Parent': 1401893918,
#              'ID': 1401893988},
#             {'Title': 'FD Mode', 'Parent': 1401893918, 'ID': 1401894041}]},
#           {'Title': 'WAAS Procedures', 'Parent': 1401889918, 'ID': 1401894118},
#           {'Title': 'Disconnect', 'Parent': 1401889918, 'ID': 1401894276}]},
#         {'Title': 'Operating Parameters',
#          'Parent': 1401734708,
#          'ID': 1401894597,
#          'children': [{'Title': 'Roll Axis Limits',
#            'Parent': 1401894597,
#            'ID': 1401894662},
#           {'Title': 'Pitch Axis Limits',
#            'Parent': 1401894597,
#            'ID': 1401894751}]}]},
#       {'Title': 'Avidyne',
#        'Parent': 1401321476,
#        'ID': 1401728478,
#        'children': [{'Title': 'EP', 'Parent': 1401728478, 'ID': 1401895674},
#         {'Title': 'EA', 'Parent': 1401728478, 'ID': 1401895739},
#         {'Title': 'IAS', 'Parent': 1401728478, 'ID': 1401895812},
#         {'Title': 'Disconnect', 'Parent': 1401728478, 'ID': 1401897057},
#         {'Title': 'Servo Malfunctions',
#          'Parent': 1401728478,
#          'ID': 1401897228},
#         {'Title': 'General Failure Mode',
#          'Parent': 1401728478,
#          'ID': 1401897315},
#         {'Title': 'PFD', 'Parent': 1401728478, 'ID': 1401897378},
#         {'Title': 'Turn Coordinator', 'Parent': 1401728478, 'ID': 1401897497},
#         {'Title': 'Miscompare', 'Parent': 1401728478, 'ID': 1401897565},
#         {'Title': 'AHRS', 'Parent': 1401728478, 'ID': 1401897657},
#         {'Title': 'Loss of Engine', 'Parent': 1401728478, 'ID': 1401897988},
#         {'Title': 'Built-in Test (BIT) Failure',
#          'Parent': 1401728478,
#          'ID': 1401898169},
#         {'Title': 'GPSS', 'Parent': 1401728478, 'ID': 1401898308},
#         {'Title': 'Nav', 'Parent': 1401728478, 'ID': 1401898386},
#         {'Title': 'Glide slope Invalid',
#          'Parent': 1401728478,
#          'ID': 1401898493},
#         {'Title': 'TC Fail', 'Parent': 1401728478, 'ID': 1401898564},
#         {'Title': 'MSR Fail', 'Parent': 1401728478, 'ID': 1401898636}]},
#       {'Title': 'Garmin',
#        'Parent': 1401321476,
#        'ID': 1401728496,
#        'children': [{'Title': 'BARO', 'Parent': 1401728496, 'ID': 1401900826},
#         {'Title': 'PFD', 'Parent': 1401728496, 'ID': 1401901167},
#         {'Title': 'ALT UNIT', 'Parent': 1401728496, 'ID': 1401901303},
#         {'Title': 'altimeter barometric',
#          'Parent': 1401728496,
#          'ID': 1401901525},
#         {'Title': 'HPA', 'Parent': 1401728496, 'ID': 1401901688},
#         {'Title': 'CDI', 'Parent': 1401728496, 'ID': 1401901748},
#         {'Title': 'OBS', 'Parent': 1401728496, 'ID': 1401901816},
#         {'Title': 'CRS', 'Parent': 1401728496, 'ID': 1401901870},
#         {'Title': 'TMR', 'Parent': 1401728496, 'ID': 1401901953},
#         {'Title': 'REF', 'Parent': 1401728496, 'ID': 1401902025},
#         {'Title': 'FMS', 'Parent': 1401728496, 'ID': 1401902110},
#         {'Title': 'CLR', 'Parent': 1401728496, 'ID': 1401902421},
#         {'Title': 'ENT', 'Parent': 1401728496, 'ID': 1401902483}]},
#       {'Title': 'Altitude', 'Parent': 1401321476, 'ID': 1401729366},
#       {'Title': 'COUPLED GO-AROUND', 'Parent': 1401321476, 'ID': 1401730694},
#       {'Title': 'STALL PROTECTION', 'Parent': 1401321476, 'ID': 1401730785}]},
#     {'Title': 'AOA',
#      'Parent': 1401320237,
#      'ID': 1401321619,
#      'children': [{'Title': 'Angle of Attack',
#        'Parent': 1401321619,
#        'ID': 1401713540},
#       {'Title': 'Garmin',
#        'Parent': 1401321619,
#        'ID': 1401714459,
#        'children': [{'Title': 'Number',
#          'Parent': 1401714459,
#          'ID': 1401714837},
#         {'Title': 'Stall', 'Parent': 1401714459, 'ID': 1401715467},
#         {'Title': 'Landing', 'Parent': 1401714459, 'ID': 1401717348}]},
#       {'Title': 'Perspective+', 'Parent': 1401321619, 'ID': 1401717960},
#       {'Title': 'HSI Map', 'Parent': 1401321619, 'ID': 1401718127},
#       {'Title': 'Colored Arcs', 'Parent': 1401321619, 'ID': 1401718380},
#       {'Title': 'Wings Level', 'Parent': 1401321619, 'ID': 1401719400},
#       {'Title': 'Air Speed', 'Parent': 1401321619, 'ID': 1401719498},
#       {'Title': 'CAS', 'Parent': 1401321619, 'ID': 1401719746}]},
#     {'Title': 'Instrument Flying',
#      'Parent': 1401320237,
#      'ID': 1401321462,
#      'children': [{'Title': 'Human Factors',
#        'Parent': 1401321462,
#        'ID': 1402243093,
#        'children': [{'Title': 'Illusion',
#          'Parent': 1402243093,
#          'ID': 1402243549},
#         {'Title': 'IMSAFE Checklist',
#          'Parent': 1402243093,
#          'ID': 1402243701}]},
#       {'Title': 'Aerodynamic Factors',
#        'Parent': 1401321462,
#        'ID': 1402243897,
#        'children': [{'Title': 'Atmosphere',
#          'Parent': 1402243897,
#          'ID': 1402244345},
#         {'Title': 'Lift', 'Parent': 1402243897, 'ID': 1402244415},
#         {'Title': 'Drag Curves', 'Parent': 1402243897, 'ID': 1402245048},
#         {'Title': 'Trim', 'Parent': 1402243897, 'ID': 1402245109},
#         {'Title': 'Slow-Speed Flight', 'Parent': 1402243897, 'ID': 1402245198},
#         {'Title': 'Climbs', 'Parent': 1402243897, 'ID': 1402245268},
#         {'Title': 'Turns', 'Parent': 1402243897, 'ID': 1402245345},
#         {'Title': 'Load', 'Parent': 1402243897, 'ID': 1402245389},
#         {'Title': 'Icing', 'Parent': 1402243897, 'ID': 1402245420}]},
#       {'Title': 'Flight Instruments',
#        'Parent': 1401321462,
#        'ID': 1402245505,
#        'children': [{'Title': 'Pitot-Static',
#          'Parent': 1402245505,
#          'ID': 1402246740,
#          'children': [{'Title': 'Vertical Speed Indicators (VSI)',
#            'Parent': 1402246740,
#            'ID': 1402246852}]},
#         {'Title': 'Compass', 'Parent': 1402245505, 'ID': 1402246895},
#         {'Title': 'Gyroscopic', 'Parent': 1402245505, 'ID': 1402246938},
#         {'Title': 'Flight Director Systems',
#          'Parent': 1402245505,
#          'ID': 1402247398,
#          'children': [{'Title': 'Horizontal Situation Indicator (HSI)',
#            'Parent': 1402247398,
#            'ID': 1402247516},
#           {'Title': 'Attitude Director Indicator (ADI)',
#            'Parent': 1402247398,
#            'ID': 1402247563}]}]},
#       {'Title': 'Airplane Attitude',
#        'Parent': 1401321462,
#        'ID': 1402247858,
#        'children': [{'Title': 'Pitch', 'Parent': 1402247858, 'ID': 1402248158},
#         {'Title': 'Bank', 'Parent': 1402247858, 'ID': 1402248186},
#         {'Title': 'Power', 'Parent': 1402247858, 'ID': 1402248241},
#         {'Title': 'Cross-Check', 'Parent': 1402247858, 'ID': 1402248301}]},
#       {'Title': 'Navigation Systems',
#        'Parent': 1401321462,
#        'ID': 1402249831,
#        'children': [{'Title': 'Nondirectional Radio Beacon (NDB)',
#          'Parent': 1402249831,
#          'ID': 1402250350,
#          'children': [{'Title': 'ADF',
#            'Parent': 1402250350,
#            'ID': 1402250748}]},
#         {'Title': 'Very-High Frequency Omnidirectional\rRange (VOR)',
#          'Parent': 1402249831,
#          'ID': 1402250855},
#         {'Title': 'Distance Measuring Equipment (DME)',
#          'Parent': 1402249831,
#          'ID': 1402251017},
#         {'Title': 'Area Navigation (RNAV)',
#          'Parent': 1402249831,
#          'ID': 1402251166,
#          'children': [{'Title': 'Long Range Navigation (LORAN)',
#            'Parent': 1402251166,
#            'ID': 1402252084},
#           {'Title': 'Inertial Navigation System (INS)',
#            'Parent': 1402251166,
#            'ID': 1402252402},
#           {'Title': 'Instrument Landing Systems (ILS)',
#            'Parent': 1402251166,
#            'ID': 1402252514},
#           {'Title': 'Simplified Directional Facility (SDF)',
#            'Parent': 1402251166,
#            'ID': 1402252670},
#           {'Title': 'Localizer Type Directional Aid (LDA)',
#            'Parent': 1402251166,
#            'ID': 1402252707},
#           {'Title': 'Microwave Landing System (MLS)',
#            'Parent': 1402251166,
#            'ID': 1402252754},
#           {'Title': 'Flight Management Systems (FMS)',
#            'Parent': 1402251166,
#            'ID': 1402252811},
#           {'Title': 'Head-up Display (HUD)',
#            'Parent': 1402251166,
#            'ID': 1402252904}]},
#         {'Title': 'National Airspace System (NAS)',
#          'Parent': 1402249831,
#          'ID': 1402253160,
#          'children': [{'Title': 'Departure Procedures (DPs)',
#            'Parent': 1402253160,
#            'ID': 1402253348},
#           {'Title': 'Standard Terminal Arrival Routes (STARs)',
#            'Parent': 1402253160,
#            'ID': 1402253409},
#           {'Title': 'Instrument Approach Procedures Charts\r(IAPs)',
#            'Parent': 1402253160,
#            'ID': 1402253480},
#           {'Title': 'Terminal Arrival Area (TAA)',
#            'Parent': 1402253160,
#            'ID': 1402253565}]}]},
#       {'Title': 'Air Traffic Control System',
#        'Parent': 1401321462,
#        'ID': 1402254021,
#        'children': [{'Title': 'Navigation/Communication (NAV/COM)',
#          'Parent': 1402254021,
#          'ID': 1402254148},
#         {'Title': 'Automated Flight Service Stations (AFSS)',
#          'Parent': 1402254021,
#          'ID': 1402254627},
#         {'Title': 'Terminal Radar Approach Control\r(TRACON)',
#          'Parent': 1402254021,
#          'ID': 1402254674},
#         {'Title': 'Tower En Route Control (TEC)',
#          'Parent': 1402254021,
#          'ID': 1402254803},
#         {'Title': 'Air Route Traffic Control Centers (ARTCC)',
#          'Parent': 1402254021,
#          'ID': 1402254878},
#         {'Title': 'Letters of Agreement (LOA)',
#          'Parent': 1402254021,
#          'ID': 1402254945}]},
#       {'Title': 'IFR Flight',
#        'Parent': 1401321462,
#        'ID': 1402255266,
#        'children': [{'Title': 'Routes',
#          'Parent': 1402255266,
#          'ID': 1402260831},
#         {'Title': 'Holding', 'Parent': 1402255266, 'ID': 1402261012},
#         {'Title': 'Approaches', 'Parent': 1402255266, 'ID': 1402261051},
#         {'Title': 'Radar', 'Parent': 1402255266, 'ID': 1402261327},
#         {'Title': 'Preflight', 'Parent': 1402255266, 'ID': 1402261701},
#         {'Title': 'Departure',
#          'Parent': 1402255266,
#          'ID': 1402261763,
#          'children': [{'Title': 'Departure Procedures (DPs)',
#            'Parent': 1402261763,
#            'ID': 1402260516}]},
#         {'Title': 'En Route', 'Parent': 1402255266, 'ID': 1402261892},
#         {'Title': 'Arrival', 'Parent': 1402255266, 'ID': 1402261968}]},
#       {'Title': 'Emergency Operations',
#        'Parent': 1401321462,
#        'ID': 1402259527,
#        'children': [{'Title': 'Weather',
#          'Parent': 1402259527,
#          'ID': 1402260164},
#         {'Title': 'Loss of Situational Awareness (SA)',
#          'Parent': 1402259527,
#          'ID': 1402260241}]}]},
#     {'Title': 'Air Conditioning',
#      'Parent': 1401320237,
#      'ID': 1401712858,
#      'children': [{'Title': 'Temperature',
#        'Parent': 1401712858,
#        'ID': 1401723574},
#       {'Title': 'Weight', 'Parent': 1401712858, 'ID': 1401723680},
#       {'Title': 'Peak load', 'Parent': 1401712858, 'ID': 1401723715},
#       {'Title': 'Models', 'Parent': 1401712858, 'ID': 1401724023},
#       {'Title': 'Installation', 'Parent': 1401712858, 'ID': 1401724183},
#       {'Title': 'Price', 'Parent': 1401712858, 'ID': 1401724193}]},
#     {'Title': 'Changing Oil',
#      'Parent': 1401320237,
#      'ID': 1401722664,
#      'children': [{'Title': 'Turbonormalized Oil Change',
#        'Parent': 1401722664,
#        'ID': 1401722702},
#       {'Title': 'Best Pracitices', 'Parent': 1401722664, 'ID': 1401722737},
#       {'Title': 'Solvent Flush', 'Parent': 1401722664, 'ID': 1401722760},
#       {'Title': 'Oil Brands',
#        'Parent': 1401722664,
#        'ID': 1401722775,
#        'children': [{'Title': 'Exxon', 'Parent': 1401722775, 'ID': 1401722783},
#         {'Title': 'Phillips', 'Parent': 1401722775, 'ID': 1401722809},
#         {'Title': 'Camguard', 'Parent': 1401722775, 'ID': 1401722835}]},
#       {'Title': 'Oil Consumption', 'Parent': 1401722664, 'ID': 1401722908},
#       {'Title': 'Oil Filter', 'Parent': 1401722664, 'ID': 1401723283},
#       {'Title': 'Oil Change interval', 'Parent': 1401722664, 'ID': 1401723303},
#       {'Title': 'Procedure', 'Parent': 1401722664, 'ID': 1401723382},
#       {'Title': 'Oil Change Entry', 'Parent': 1401722664, 'ID': 1401723591},
#       {'Title': 'Moldable Funnel', 'Parent': 1401722664, 'ID': 1401723966},
#       {'Title': 'Pressurize the Crankcase',
#        'Parent': 1401722664,
#        'ID': 1401724028}]},
#     {'Title': 'Cold weather operations',
#      'Parent': 1401320237,
#      'ID': 1404422063,
# ...
#       {'Title': 'Phillips', 'Parent': 1401722775, 'ID': 1401722809},
#       {'Title': 'Camguard', 'Parent': 1401722775, 'ID': 1401722835}]},
#     {'Title': 'Oil Consumption', 'Parent': 1401722664, 'ID': 1401722908},
#     {'Title': 'Oil Filter', 'Parent': 1401722664, 'ID': 1401723283},
#     {'Title': 'Oil Change interval', 'Parent': 1401722664, 'ID': 1401723303},
#     {'Title': 'Procedure', 'Parent': 1401722664, 'ID': 1401723382},
#     {'Title': 'Oil Change Entry', 'Parent': 1401722664, 'ID': 1401723591},
#     {'Title': 'Moldable Funnel', 'Parent': 1401722664, 'ID': 1401723966},
#     {'Title': 'Pressurize the Crankcase',
#      'Parent': 1401722664,
#      'ID': 1401724028}]},
#   {'Title': 'Turbonormalized Oil Change',
#    'Parent': 1401722664,
#    'ID': 1401722702},
#   {'Title': 'Best Pracitices', 'Parent': 1401722664, 'ID': 1401722737},
#   {'Title': 'Solvent Flush', 'Parent': 1401722664, 'ID': 1401722760},
#   {'Title': 'Oil Brands',
#    'Parent': 1401722664,
#    'ID': 1401722775,
#    'children': [{'Title': 'Exxon', 'Parent': 1401722775, 'ID': 1401722783},
#     {'Title': 'Phillips', 'Parent': 1401722775, 'ID': 1401722809},
#     {'Title': 'Camguard', 'Parent': 1401722775, 'ID': 1401722835}]},
#   {'Title': 'Exxon', 'Parent': 1401722775, 'ID': 1401722783},
#   {'Title': 'Phillips', 'Parent': 1401722775, 'ID': 1401722809},
#   {'Title': 'Camguard', 'Parent': 1401722775, 'ID': 1401722835},
#   {'Title': 'Oil Consumption', 'Parent': 1401722664, 'ID': 1401722908},
#   {'Title': 'Oil Filter', 'Parent': 1401722664, 'ID': 1401723283},
#   {'Title': 'Oil Change interval', 'Parent': 1401722664, 'ID': 1401723303},
#   {'Title': 'Procedure', 'Parent': 1401722664, 'ID': 1401723382},
#   {'Title': 'Oil Change Entry', 'Parent': 1401722664, 'ID': 1401723591},
#   {'Title': 'Moldable Funnel', 'Parent': 1401722664, 'ID': 1401723966},
#   {'Title': 'Pressurize the Crankcase',
#    'Parent': 1401722664,
#    'ID': 1401724028},
#   {'Title': 'Cold weather operations',
#    'Parent': 1401320237,
#    'ID': 1404422063,
#    'children': [{'Title': 'Block the Skis',
#      'Parent': 1404422063,
#      'ID': 1404422231},
#     {'Title': 'Warming Up', 'Parent': 1404422063, 'ID': 1404422262},
#     {'Title': 'Icing', 'Parent': 1404422063, 'ID': 1404422333},
#     {'Title': 'Carb Heat', 'Parent': 1404422063, 'ID': 1404422374},
#     {'Title': 'Brake Easy', 'Parent': 1404422063, 'ID': 1404422414},
#     {'Title': 'Weather', 'Parent': 1404422063, 'ID': 1404422448},
#     {'Title': 'Flight Plan', 'Parent': 1404422063, 'ID': 1404422500},
#     {'Title': 'Fuel', 'Parent': 1404422063, 'ID': 1404422540},
#     {'Title': 'Cell', 'Parent': 1404422063, 'ID': 1404422587},
#     {'Title': 'Cross Wind', 'Parent': 1404422063, 'ID': 1404422620}]},
#   {'Title': 'Block the Skis', 'Parent': 1404422063, 'ID': 1404422231},
#   {'Title': 'Warming Up', 'Parent': 1404422063, 'ID': 1404422262},
#   {'Title': 'Icing', 'Parent': 1404422063, 'ID': 1404422333},
#   {'Title': 'Carb Heat', 'Parent': 1404422063, 'ID': 1404422374},
#   {'Title': 'Brake Easy', 'Parent': 1404422063, 'ID': 1404422414},
#   {'Title': 'Weather', 'Parent': 1404422063, 'ID': 1404422448},
#   {'Title': 'Flight Plan', 'Parent': 1404422063, 'ID': 1404422500},
#   {'Title': 'Fuel', 'Parent': 1404422063, 'ID': 1404422540},
#   {'Title': 'Cell', 'Parent': 1404422063, 'ID': 1404422587},
#   {'Title': 'Cross Wind', 'Parent': 1404422063, 'ID': 1404422620},
#   {'Title': 'Pre buy Inspection',
#    'Parent': 1401320237,
#    'ID': 1404458822,
#    'children': [{'Title': 'Airframe',
#      'Parent': 1404458822,
#      'ID': 1404460488,
#      'children': [{'Title': 'Paint', 'Parent': 1404460488, 'ID': 1404460535},
#       {'Title': 'Corrosion', 'Parent': 1404460488, 'ID': 1404460559},
#       {'Title': 'Fabric', 'Parent': 1404460488, 'ID': 1404460585},
#       {'Title': 'Attachment points', 'Parent': 1404460488, 'ID': 1404461451},
#       {'Title': 'Control cables/pulleys',
#        'Parent': 1404460488,
#        'ID': 1404461502},
#       {'Title': 'Control surfaces', 'Parent': 1404460488, 'ID': 1404461550},
#       {'Title': 'Fuel tanks/lines', 'Parent': 1404460488, 'ID': 1404461590},
#       {'Title': 'Doors/windows, emergency exits',
#        'Parent': 1404460488,
#        'ID': 1404461623}]},
#     {'Title': 'Landing Gear',
#      'Parent': 1404458822,
#      'ID': 1404461735,
#      'children': [{'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461777},
#       {'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461810},
#       {'Title': 'Shock absorbing system',
#        'Parent': 1404461735,
#        'ID': 1404461828},
#       {'Title': 'Scissor links', 'Parent': 1404461735, 'ID': 1404461856},
#       {'Title': 'Retraction system', 'Parent': 1404461735, 'ID': 1404461878},
#       {'Title': 'Shimmy damper', 'Parent': 1404461735, 'ID': 1404462249},
#       {'Title': 'Gear attach points', 'Parent': 1404461735, 'ID': 1404462270},
#       {'Title': 'Microswitches', 'Parent': 1404461735, 'ID': 1404462293}]},
#     {'Title': 'Cabin Interior',
#      'Parent': 1404458822,
#      'ID': 1404462343,
#      'children': [{'Title': 'Cockpit controls',
#        'Parent': 1404462343,
#        'ID': 1404462377},
#       {'Title': 'Circuit breakers/switches',
#        'Parent': 1404462343,
#        'ID': 1404462427},
#       {'Title': 'Instruments', 'Parent': 1404462343, 'ID': 1404462448},
#       {'Title': 'Avionics', 'Parent': 1404462343, 'ID': 1404462467},
#       {'Title': 'Seatbelts', 'Parent': 1404462343, 'ID': 1404462507},
#       {'Title': 'Seats/tracks/frames', 'Parent': 1404462343, 'ID': 1404462553},
#       {'Title': 'Ventilation/heat', 'Parent': 1404462343, 'ID': 1404462593},
#       {'Title': 'Interior fabric', 'Parent': 1404462343, 'ID': 1404462614},
#       {'Title': 'Door/window seals', 'Parent': 1404462343, 'ID': 1404462632},
#       {'Title': 'Window/windshields', 'Parent': 1404462343, 'ID': 1404462663},
#       {'Title': 'Lighting', 'Parent': 1404462343, 'ID': 1404462686}]},
#     {'Title': 'Engine Systems',
#      'Parent': 1404458822,
#      'ID': 1404462697,
#      'children': [{'Title': 'Corrosion',
#        'Parent': 1404462697,
#        'ID': 1404462749},
#       {'Title': 'Induction system', 'Parent': 1404462697, 'ID': 1404462777},
#       {'Title': 'Turbocharging system',
#        'Parent': 1404462697,
#        'ID': 1404462847},
#       {'Title': 'Exhaust system', 'Parent': 1404462697, 'ID': 1404462868},
#       {'Title': 'Ignition system', 'Parent': 1404462697, 'ID': 1404462894},
#       {'Title': 'Electrical system', 'Parent': 1404462697, 'ID': 1404462924},
#       {'Title': 'Battery', 'Parent': 1404462697, 'ID': 1404462960},
#       {'Title': 'Cooling baffles', 'Parent': 1404462697, 'ID': 1404462993},
#       {'Title': 'Control cables', 'Parent': 1404462697, 'ID': 1404463028},
#       {'Title': 'Lubrication system', 'Parent': 1404462697, 'ID': 1404463061},
#       {'Title': 'Starter', 'Parent': 1404462697, 'ID': 1404463090},
#       {'Title': 'Filters', 'Parent': 1404462697, 'ID': 1404463136},
#       {'Title': 'Vacuum system', 'Parent': 1404462697, 'ID': 1404463159},
#       {'Title': 'Fuel system', 'Parent': 1404462697, 'ID': 1404463185},
#       {'Title': 'Engine mounts', 'Parent': 1404462697, 'ID': 1404463226},
#       {'Title': 'Seals', 'Parent': 1404462697, 'ID': 1404463248},
#       {'Title': 'General condition', 'Parent': 1404462697, 'ID': 1404463282}]},
#     {'Title': 'Propeller',
#      'Parent': 1404458822,
#      'ID': 1404463329,
#      'children': [{'Title': 'Blade conditions',
#        'Parent': 1404463329,
#        'ID': 1404463359},
#       {'Title': 'Hub conditions', 'Parent': 1404463329, 'ID': 1404463434},
#       {'Title': 'Governor', 'Parent': 1404463329, 'ID': 1404463583},
#       {'Title': 'Spinner', 'Parent': 1404463329, 'ID': 1404463637},
#       {'Title': 'Seals', 'Parent': 1404463329, 'ID': 1404463671},
#       {'Title': 'Deicing', 'Parent': 1404463329, 'ID': 1404463802}]},
#     {'Title': 'Cylinders',
#      'Parent': 1404458822,
#      'ID': 1404463845,
#      'children': [{'Title': 'Compression',
#        'Parent': 1404463845,
#        'ID': 1404463873},
#       {'Title': 'Oil Consumption', 'Parent': 1404463845, 'ID': 1404463909}]}]},
#   {'Title': 'Airframe',
#    'Parent': 1404458822,
#    'ID': 1404460488,
#    'children': [{'Title': 'Paint', 'Parent': 1404460488, 'ID': 1404460535},
#     {'Title': 'Corrosion', 'Parent': 1404460488, 'ID': 1404460559},
#     {'Title': 'Fabric', 'Parent': 1404460488, 'ID': 1404460585},
#     {'Title': 'Attachment points', 'Parent': 1404460488, 'ID': 1404461451},
#     {'Title': 'Control cables/pulleys',
#      'Parent': 1404460488,
#      'ID': 1404461502},
#     {'Title': 'Control surfaces', 'Parent': 1404460488, 'ID': 1404461550},
#     {'Title': 'Fuel tanks/lines', 'Parent': 1404460488, 'ID': 1404461590},
#     {'Title': 'Doors/windows, emergency exits',
#      'Parent': 1404460488,
#      'ID': 1404461623}]},
#   {'Title': 'Paint', 'Parent': 1404460488, 'ID': 1404460535},
#   {'Title': 'Corrosion', 'Parent': 1404460488, 'ID': 1404460559},
#   {'Title': 'Fabric', 'Parent': 1404460488, 'ID': 1404460585},
#   {'Title': 'Attachment points', 'Parent': 1404460488, 'ID': 1404461451},
#   {'Title': 'Control cables/pulleys', 'Parent': 1404460488, 'ID': 1404461502},
#   {'Title': 'Control surfaces', 'Parent': 1404460488, 'ID': 1404461550},
#   {'Title': 'Fuel tanks/lines', 'Parent': 1404460488, 'ID': 1404461590},
#   {'Title': 'Doors/windows, emergency exits',
#    'Parent': 1404460488,
#    'ID': 1404461623},
#   {'Title': 'Landing Gear',
#    'Parent': 1404458822,
#    'ID': 1404461735,
#    'children': [{'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461777},
#     {'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461810},
#     {'Title': 'Shock absorbing system',
#      'Parent': 1404461735,
#      'ID': 1404461828},
#     {'Title': 'Scissor links', 'Parent': 1404461735, 'ID': 1404461856},
#     {'Title': 'Retraction system', 'Parent': 1404461735, 'ID': 1404461878},
#     {'Title': 'Shimmy damper', 'Parent': 1404461735, 'ID': 1404462249},
#     {'Title': 'Gear attach points', 'Parent': 1404461735, 'ID': 1404462270},
#     {'Title': 'Microswitches', 'Parent': 1404461735, 'ID': 1404462293}]},
#   {'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461777},
#   {'Title': 'Tires', 'Parent': 1404461735, 'ID': 1404461810},
#   {'Title': 'Shock absorbing system', 'Parent': 1404461735, 'ID': 1404461828},
#   {'Title': 'Scissor links', 'Parent': 1404461735, 'ID': 1404461856},
#   {'Title': 'Retraction system', 'Parent': 1404461735, 'ID': 1404461878},
#   {'Title': 'Shimmy damper', 'Parent': 1404461735, 'ID': 1404462249},
#   {'Title': 'Gear attach points', 'Parent': 1404461735, 'ID': 1404462270},
#   {'Title': 'Microswitches', 'Parent': 1404461735, 'ID': 1404462293},
#   {'Title': 'Cabin Interior',
#    'Parent': 1404458822,
#    'ID': 1404462343,
#    'children': [{'Title': 'Cockpit controls',
#      'Parent': 1404462343,
#      'ID': 1404462377},
#     {'Title': 'Circuit breakers/switches',
#      'Parent': 1404462343,
#      'ID': 1404462427},
#     {'Title': 'Instruments', 'Parent': 1404462343, 'ID': 1404462448},
#     {'Title': 'Avionics', 'Parent': 1404462343, 'ID': 1404462467},
#     {'Title': 'Seatbelts', 'Parent': 1404462343, 'ID': 1404462507},
#     {'Title': 'Seats/tracks/frames', 'Parent': 1404462343, 'ID': 1404462553},
#     {'Title': 'Ventilation/heat', 'Parent': 1404462343, 'ID': 1404462593},
#     {'Title': 'Interior fabric', 'Parent': 1404462343, 'ID': 1404462614},
#     {'Title': 'Door/window seals', 'Parent': 1404462343, 'ID': 1404462632},
#     {'Title': 'Window/windshields', 'Parent': 1404462343, 'ID': 1404462663},
#     {'Title': 'Lighting', 'Parent': 1404462343, 'ID': 1404462686}]},
#   {'Title': 'Cockpit controls', 'Parent': 1404462343, 'ID': 1404462377},
#   {'Title': 'Circuit breakers/switches',
#    'Parent': 1404462343,
#    'ID': 1404462427},
#   {'Title': 'Instruments', 'Parent': 1404462343, 'ID': 1404462448},
#   {'Title': 'Avionics', 'Parent': 1404462343, 'ID': 1404462467},
#   {'Title': 'Seatbelts', 'Parent': 1404462343, 'ID': 1404462507},
#   {'Title': 'Seats/tracks/frames', 'Parent': 1404462343, 'ID': 1404462553},
#   {'Title': 'Ventilation/heat', 'Parent': 1404462343, 'ID': 1404462593},
#   {'Title': 'Interior fabric', 'Parent': 1404462343, 'ID': 1404462614},
#   {'Title': 'Door/window seals', 'Parent': 1404462343, 'ID': 1404462632},
#   {'Title': 'Window/windshields', 'Parent': 1404462343, 'ID': 1404462663},
#   {'Title': 'Lighting', 'Parent': 1404462343, 'ID': 1404462686},
#   {'Title': 'Engine Systems',
#    'Parent': 1404458822,
#    'ID': 1404462697,
#    'children': [{'Title': 'Corrosion', 'Parent': 1404462697, 'ID': 1404462749},
#     {'Title': 'Induction system', 'Parent': 1404462697, 'ID': 1404462777},
#     {'Title': 'Turbocharging system', 'Parent': 1404462697, 'ID': 1404462847},
#     {'Title': 'Exhaust system', 'Parent': 1404462697, 'ID': 1404462868},
#     {'Title': 'Ignition system', 'Parent': 1404462697, 'ID': 1404462894},
#     {'Title': 'Electrical system', 'Parent': 1404462697, 'ID': 1404462924},
#     {'Title': 'Battery', 'Parent': 1404462697, 'ID': 1404462960},
#     {'Title': 'Cooling baffles', 'Parent': 1404462697, 'ID': 1404462993},
#     {'Title': 'Control cables', 'Parent': 1404462697, 'ID': 1404463028},
#     {'Title': 'Lubrication system', 'Parent': 1404462697, 'ID': 1404463061},
#     {'Title': 'Starter', 'Parent': 1404462697, 'ID': 1404463090},
#     {'Title': 'Filters', 'Parent': 1404462697, 'ID': 1404463136},
#     {'Title': 'Vacuum system', 'Parent': 1404462697, 'ID': 1404463159},
#     {'Title': 'Fuel system', 'Parent': 1404462697, 'ID': 1404463185},
#     {'Title': 'Engine mounts', 'Parent': 1404462697, 'ID': 1404463226},
#     {'Title': 'Seals', 'Parent': 1404462697, 'ID': 1404463248},
#     {'Title': 'General condition', 'Parent': 1404462697, 'ID': 1404463282}]},
#   {'Title': 'Corrosion', 'Parent': 1404462697, 'ID': 1404462749},
#   {'Title': 'Induction system', 'Parent': 1404462697, 'ID': 1404462777},
#   {'Title': 'Turbocharging system', 'Parent': 1404462697, 'ID': 1404462847},
#   {'Title': 'Exhaust system', 'Parent': 1404462697, 'ID': 1404462868},
#   {'Title': 'Ignition system', 'Parent': 1404462697, 'ID': 1404462894},
#   {'Title': 'Electrical system', 'Parent': 1404462697, 'ID': 1404462924},
#   {'Title': 'Battery', 'Parent': 1404462697, 'ID': 1404462960},
#   {'Title': 'Cooling baffles', 'Parent': 1404462697, 'ID': 1404462993},
#   {'Title': 'Control cables', 'Parent': 1404462697, 'ID': 1404463028},
#   {'Title': 'Lubrication system', 'Parent': 1404462697, 'ID': 1404463061},
#   {'Title': 'Starter', 'Parent': 1404462697, 'ID': 1404463090},
#   {'Title': 'Filters', 'Parent': 1404462697, 'ID': 1404463136},
#   {'Title': 'Vacuum system', 'Parent': 1404462697, 'ID': 1404463159},
#   {'Title': 'Fuel system', 'Parent': 1404462697, 'ID': 1404463185},
#   {'Title': 'Engine mounts', 'Parent': 1404462697, 'ID': 1404463226},
#   {'Title': 'Seals', 'Parent': 1404462697, 'ID': 1404463248},
#   {'Title': 'General condition', 'Parent': 1404462697, 'ID': 1404463282},
#   {'Title': 'Propeller',
#    'Parent': 1404458822,
#    'ID': 1404463329,
#    'children': [{'Title': 'Blade conditions',
#      'Parent': 1404463329,
#      'ID': 1404463359},
#     {'Title': 'Hub conditions', 'Parent': 1404463329, 'ID': 1404463434},
#     {'Title': 'Governor', 'Parent': 1404463329, 'ID': 1404463583},
#     {'Title': 'Spinner', 'Parent': 1404463329, 'ID': 1404463637},
#     {'Title': 'Seals', 'Parent': 1404463329, 'ID': 1404463671},
#     {'Title': 'Deicing', 'Parent': 1404463329, 'ID': 1404463802}]},
#   {'Title': 'Blade conditions', 'Parent': 1404463329, 'ID': 1404463359},
#   {'Title': 'Hub conditions', 'Parent': 1404463329, 'ID': 1404463434},
#   {'Title': 'Governor', 'Parent': 1404463329, 'ID': 1404463583},
#   {'Title': 'Spinner', 'Parent': 1404463329, 'ID': 1404463637},
#   {'Title': 'Seals', 'Parent': 1404463329, 'ID': 1404463671},
#   {'Title': 'Deicing', 'Parent': 1404463329, 'ID': 1404463802},
#   {'Title': 'Cylinders',
#    'Parent': 1404458822,
#    'ID': 1404463845,
#    'children': [{'Title': 'Compression',
#      'Parent': 1404463845,
#      'ID': 1404463873},
#     {'Title': 'Oil Consumption', 'Parent': 1404463845, 'ID': 1404463909}]},
#   {'Title': 'Compression', 'Parent': 1404463845, 'ID': 1404463873},
#   {'Title': 'Oil Consumption', 'Parent': 1404463845, 'ID': 1404463909}]}

# %%
expression = jmespath.compile("data[?Title =='Lean of Peak'].children[].Title")
expression.search(data)
# Out:
# ['LOP',
#  'Mixture',
#  'Red Box Table',
#  'Red Fin',
#  'WOTLOPSOP',
#  'Cylinder Pressure']

# %%
expression = jmespath.compile("data[?Title =='Lean of Peak'].parent.Title")
expression.search(data)
# Out:
# []

# %%
# Out:
# ['LOP',
#  'Mixture',
#  'Red Box Table',
#  'Red Fin',
#  'WOTLOPSOP',
#  'Cylinder Pressure']

# %% [markdown]
# ### Data Sources Integration

# %%
data = []
for filename in glob.glob('*.csv'):
    data.append(filename)
data
# Out:
# ['Parsed Magazine.csv', 'wiki_formal_total_clean.csv', 'COPA_Blogs.csv']

# %%
wiki = pd.read_csv(data[1])
wiki = wiki[['Date', 'Title', 'Content', 'Author','Like']]
wiki['Author'] = [a.strip() for a in wiki['Author']]
wiki['Comment'] = 0
wiki['Resource'] = 'Wiki'

# %%
magazine = pd.read_csv(data[0])
magazine_date_list = list(magazine['Magazine'].unique())
# Get the month of magazine from its name
# Since the the COPA magazines are released monthly, so it only has year and month
# in its date column. In this case we just assume all magazines were released on the 
# first day of that month.
magazine_date_dict = {magazine_date_list[0]: '2015-01-01', magazine_date_list[1]: '2019-01-01',
                      magazine_date_list[2]: '2015-07-01', magazine_date_list[3]: '2019-04-01',
                      magazine_date_list[4]: '2019-06-01', magazine_date_list[5]: '2018-01-01',
                      magazine_date_list[6]: '2017-09-01', magazine_date_list[7]: '2016-09-01',
                      magazine_date_list[8]: '2017-11-01', magazine_date_list[9]: '2015-05-01',
                      magazine_date_list[10]: '2015-09-01', magazine_date_list[11]: '2006-09-01', 
                      magazine_date_list[12]: '2018-06-01', magazine_date_list[13]: '2019-07-01',
                      magazine_date_list[14]: '2017-04-01', magazine_date_list[15]: '2016-04-01',
                      magazine_date_list[16]: '2018-11-01', magazine_date_list[17]: '2015-09-01',
                      magazine_date_list[18]: '2019-03-01', magazine_date_list[19]: '2006-11-01',
                      magazine_date_list[20]: '2016-01-01', magazine_date_list[21]: '2019-05-01',
                      magazine_date_list[22]: '2016-03-01', magazine_date_list[23]: '2016-05-01',
                      magazine_date_list[24]: '2006-07-01', magazine_date_list[25]: '2017-06-01',
                      magazine_date_list[26]: '2018-07-01', magazine_date_list[27]: '2018-09-01',
                      magazine_date_list[28]: '2017-01-01', magazine_date_list[29]: '2012-11-01'}
magazine['Magazine'] = magazine['Magazine'].map(magazine_date_dict)
magazine.columns = ['Date', 'Title', 'Content', 'Author']
magazine['Like'] = 0
magazine['Comment'] = 0
magazine['Resource'] = 'Magazine'

# %%
blog = pd.read_csv(data[2], encoding = 'unicode_escape')
blog = blog[['Date', 'Title', 'Body', 'Author', 'Like','Comment']]
blog.columns = ['Date', 'Title', 'Content', 'Author', 'Like','Comment']
blog['Date'] = [d.split(' ')[0].split('/')[2] + '-' + d.split(' ')[0].split('/')[0] for d in blog['Date']]
blog['Date'] = blog['Date'].map(lambda x: x + '-01')
blog['Resource'] = 'Blog'

# %%
pdList = [magazine, wiki, blog]
# Combine three datasets together
df = pd.concat(pdList)
df.reset_index(drop = True, inplace = True)

# %%
#Ranking the source, blog is the most important source so have 3
raw_data = {'Resource': ['Wiki','Blog','Magazine'], 'SourceScore': [1, 2, 3]}
Source_tb = pd.DataFrame(raw_data, columns = ['Resource', 'SourceScore'])
#add source score to the main table
df = pd.merge(df, Source_tb, left_on = 'Resource', right_on = 'Resource')

# %% [markdown]
# # Generate Attributes

# %% [markdown]
# __Generate Recency Score__

# %%
def  Calculate_RecencyScore(date):
    '''
    Recency Rate = log( 1 + 1/(days between the post date and current date + 1))
    '''
    date_datetime = datetime.strptime(date, '%Y-%m-%d').date()
    rececncy_rate = math.log10(1/(((datetime.date(datetime.now()))-date_datetime).days+1)+1)
    return rececncy_rate
    

df['RecencyRate'] = df['Date'].map(lambda y: Calculate_RecencyScore(y))

# %% [markdown]
# __Generate Author Score__

# %%
def Calculate_AuthorScore(author):
    '''
    AuthorScore = Number of posts of specified content source * pre-determined weight
    '''
    author_score = df[df['Author'] == author]['SourceScore'].sum()
    return author_score

author_list = list(df['Author'].unique())
df['AuthorScore'] = df['Author'].map(lambda x: Calculate_AuthorScore(x), author_list)

# %% [markdown]
# __Normalization__

# %%
def Normalization(col):
    nomolized_col = (df[col] - df[col].mean()) / df.loc[:, col].std()
    return nomolized_col

df['RecencyRate'] = Normalization('RecencyRate')
df['AuthorScore'] = Normalization('AuthorScore')

# %%
df.head()
# Out:
#          Date               Title  \
# 0  2015-01-01  President's Column
# 1  2015-01-01           COPA News
# 2  2015-01-01       Regional News
# 3  2015-01-01  Cirrus Perspective
# 4  2015-01-01    Member Spotlight
#
#                                              Content          Author  Like  \
# 0  JANUARY FEBRUARY 20154CIRRUS PILOTAs this is b...             NaN     0
# 1  JANUARY FEBRUARY 20156CIRRUS PILOTWith this is...             NaN     0
# 2  JANUARY FEBRUARY 201512CIRRUS PILOTby GIL WILL...  GIL WILLIAMSON     0
# 3  JANUARY FEBRUARY 201518CIRRUS PILOTIts hard to...             NaN     0
# 4  JANUARY FEBRUARY 201522CIRRUS PILOTCirrus Pilo...    KIM BLONIGEN     0
#
#    Comment  Resource  SourceScore  RecencyRate  AuthorScore
# 0        0  Magazine            3    -0.468124    -1.209951
# 1        0  Magazine            3    -0.468124    -1.209951
# 2        0  Magazine            3    -0.468124     0.211050
# 3        0  Magazine            3    -0.468124    -1.209951
# 4        0  Magazine            3    -0.468124     0.211050
